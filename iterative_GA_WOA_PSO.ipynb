# %% [markdown]
# <a href="https://colab.research.google.com/github/Matteo7100/THESIS_PROJECT/blob/main/iterative_GA_WOA_PSO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
import time
import matplotlib.pyplot as plt
import cProfile as profile
import math
from tensorflow.keras.utils import plot_model
import random
import pandas as pd

# %%
#@title Class net structure

class NetStructure:
    def __init__(self, input_dim, output_dim):
        self.input_dim  = input_dim
        self.n_hidden   = 0
        self.hidden_dim = []
        self.output_dim = output_dim
        self.activation = []

    def add_hidden(self, hidden_dim, activation = 'linear'):
        self.n_hidden += 1
        self.hidden_dim.append(hidden_dim)
        self.activation.append(activation)

    def get_input_dim(self):
        return self.input_dim

    def get_output_dim(self):
        return self.output_dim

    def get_num_hidden(self):
        return self.n_hidden

    def get_hidden_dim(self, index):
        return self.hidden_dim[index]

    def get_activation(self, index):
        return self.activation[index]

    def print(self):
        print("----------------------")
        print("    Input dim:", self.input_dim)
        for i in range(self.n_hidden):
            print(" Hidden", i+1, "dim:", self.hidden_dim[i], "- activation:", self.activation[i])
        print("   Output dim:", self.output_dim)
        print("----------------------")

# %%
#@title Meta

class Meta:
    def __init__(self, net_structure):
        self.net_structure  = net_structure

        # I define the mdoel on the basis of the structure i handed it
        self.model = tf.keras.Sequential()
        self.model.add(tf.keras.layers.Dense(net_structure.get_hidden_dim(0), activation=net_structure.get_activation(0), input_dim=net_structure.get_input_dim()))
        for i in range(1, net_structure.get_num_hidden()):
            self.model.add(tf.keras.layers.Dense(net_structure.get_hidden_dim(i), activation=net_structure.get_activation(i)))
        self.model.add(tf.keras.layers.Dense(net_structure.get_output_dim()))


        # save the number of model parameters
        self.num_parameters = self.model.count_params()

    def get_model(self):
        return self.model

    def set_num_iterations(self, num_iterations):
        self.num_iterations = num_iterations

    def set_population_size(self, population_size):
        self.population_size = population_size

    # def is_in_domain(self, x):
    #   if (x < self.domain[0] or x > self.domain[1]):
    #       return False
    #   return True

    def update_model_with_parameters(self, opt_par):
        nl = len(self.model.layers)
        wbindex = 0
        for p in range(0, nl):
          W = opt_par[wbindex:(wbindex + self.model.layers[p].input.shape[1] * self.model.layers[p].output.shape[1])]
          b = opt_par[(wbindex + self.model.layers[p].input.shape[1] * self.model.layers[p].output.shape[1]):(wbindex + self.model.layers[p].count_params())]
          self.model.layers[p].set_weights([W.reshape(self.model.layers[p].input.shape[1], self.model.layers[p].output.shape[1]), b])
          wbindex = (wbindex + self.model.layers[p].count_params())
    # the objective function used is MSE
    def objective_function(self, n_samples):
        X = np.random.uniform(low=0, high=1, size=(n_samples, 2))
        y_pred = self.model.predict(X, verbose = 0)
        Y = X[:,0]**2 + X[:,1]**2
        rest = np.mean((y_pred.flatten() - Y)**2)

        return rest

# %%
#@title Class GA

class GA(Meta):

    def __init__(self, net_structure):
        super().__init__(net_structure)
        self.x_rate = 0.60
        self.mutation_rate = 0.1

    def set_options(self, x_rate = 0.60, mutation_rate = 0.1):
        self.x_rate = x_rate
        self.mutation_rate = mutation_rate

    def set_max_x(self, max_x):
        self.max_x = max_x

    def natural_selection(self, population, costs):
      # transform the x_rate into a numerical value indicating how far up the population vector index I must go
        n = int(self.x_rate * self.population_size)
        costs = costs[:len(population)]
        indices = np.argsort(costs)
      # I sort the population according to the value of the cost function to identify which individuals are the best performers
        sorted_population = population[indices]
        selected_population = sorted_population[:n]
        return selected_population

    #mating functions: Roulette Wheel weighting
    def roulette_wheel_weighting(self, population, costs):
        probability = []
        costs =  np.sort(costs)
        ordinated_costs = costs[:len(population)]
        cost_n = costs[-1]
        for i in range(len(ordinated_costs)):
    # I normalize the values of the cost function so that the sum is one
            probability.append((ordinated_costs[i] - cost_n) / (sum(ordinated_costs) - (cost_n * len(ordinated_costs))))
        rand = np.random.uniform(probability[-1], 1)
    # find the chromosome that corresponds to the interval in which rand falls
        for q in range(len(probability)):
            if rand > probability[q]:
                chosen_chromosome =  population[q]
                return chosen_chromosome


    def mating(self, population, costs):
        father = self.roulette_wheel_weighting(population, costs)
        mother = self.roulette_wheel_weighting(population, costs)
        beta = np.random.uniform(low = 0, high = 10, size = (self.num_parameters))
        #crossover: blending method
        offspring_1 = father - np.multiply(beta, mother - father)
        offspring_2 = mother + np.multiply(beta, mother - father)
        # adding new generations to the population
        population = np.vstack((population, offspring_1))
        population = np.vstack((population, offspring_2))
        return population

    def mutation(self, population, best_index):
    # number of mutation
        mutation_number = int(self.mutation_rate * self.num_parameters * len(population))
    # repeat mutation_number times: I take any chromosome and modify any gene of it
        for t in range(mutation_number):
            chromosome_choice = np.random.randint(0, len(population)-1)
            if t == chromosome_choice and best_index != t:
                for p in range(len(population)):
                    gene_choice = np.random.randint(0, self.num_parameters-1)
                    if p == gene_choice:
                        population[t][gene_choice] = np.random.uniform(low = -self.max_x, high = self.max_x)
        return population


    def optimize(self):
        population = np.random.uniform(low = -self.max_x, high = self.max_x, size = (self.population_size, self.num_parameters ))
        best_positions = np.copy(population)
        best_scores = np.array([self.num_parameters] * self.population_size)
        global_best_position = np.copy(population[0])
        global_best_score = 1e10
        nl = len(self.model.layers)
        len_population = len(population)
        costs = np.zeros(len(population))

        for iteration in range(self.num_iterations):
            tic_global = time.perf_counter()

            for i in range(len_population):
                genome = population[i,]
                best_index = 0

                wbindex = 0

                for p in range(0, nl):
                  W = genome[wbindex:(wbindex + self.model.layers[p].input.shape[1] * self.model.layers[p].output.shape[1])]
                  b = genome[(wbindex + self.model.layers[p].input.shape[1] * self.model.layers[p].output.shape[1]):(wbindex + self.model.layers[p].count_params())]
                  self.model.layers[p].set_weights([W.reshape(self.model.layers[p].input.shape[1], self.model.layers[p].output.shape[1]), b])
                  wbindex = (wbindex + self.model.layers[p].count_params())


                fitness = self.objective_function(n_samples=1000)
                costs[i] = self.objective_function(n_samples=1000)



                # print(fitness)

                if  fitness < best_scores[i]:
                    best_scores[i] = fitness
                    best_positions[i] = np.copy(population[i])

                if  fitness < global_best_score:
                    global_best_score = fitness
                    best_index = i
                    global_best_position = np.copy(population[i])


            population = self.natural_selection(population, costs)
            population = self.mating(population, costs)
            population = self.mutation(population, best_index)

            toc_global = time.perf_counter()
            len_population = len(population)

            # check that the adjourned positions are not outside the domain
            population  = np.minimum(population,  self.max_x)
            population  = np.maximum(population, -self.max_x)


            print("Iteration #%d - Objective function value: %5.2f - time: %0.3f " % (iteration, global_best_score, toc_global - tic_global))
            if (global_best_score == 0):
                break


        return global_best_position

    def predict(self, x = None):
        return self.model.predict(x)

# %%
#@title Code for traing and test with GA

net = NetStructure(input_dim=2, output_dim=1)
net.add_hidden(hidden_dim=5)


met = GA(net)
met.set_population_size(50)
met.set_max_x(1.5)

sample_size = 1000
domain = [-1, 1]


repetitions = 100
ga_variables = []

# TRAIN
for i in range(repetitions):
    x = np.random.randint(6, 18)
    met.set_num_iterations(x)
    time_start = time.perf_counter()
    optimized_params = met.optimize()
    time_end = time.perf_counter()
    time_ga = time_end - time_start
    met.update_model_with_parameters(optimized_params)

    X_test = np.random.uniform(low=1, high=2, size=(sample_size, 2))

    # TEST
    y_pred_test = met.predict(X_test)
    mse_test = np.mean((y_pred_test.flatten() - y_pred_test)**2)
    print(f"Mean Squared Error on Test Set: {mse_test}")

    variables = [[met.population_size, x, met.max_x, time_ga, mse_test]]
    ga_variables = ga_variables + variables

    print("repetition =",i)

print(ga_variables)
# Out:
# Iteration #0 - Objective function value:  0.12 - time: 14.098
# Iteration #1 - Objective function value:  0.11 - time: 8.612
# Iteration #2 - Objective function value:  0.11 - time: 8.960
# Iteration #3 - Objective function value:  0.11 - time: 8.794
# Iteration #4 - Objective function value:  0.10 - time: 8.171
# Iteration #5 - Objective function value:  0.10 - time: 8.994
# Iteration #6 - Objective function value:  0.10 - time: 9.385
# Iteration #7 - Objective function value:  0.10 - time: 7.836
# Iteration #8 - Objective function value:  0.10 - time: 8.851
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.22222985327243805
# repetition = 0
# Iteration #0 - Objective function value:  0.22 - time: 13.207
# Iteration #1 - Objective function value:  0.22 - time: 8.758
# Iteration #2 - Objective function value:  0.22 - time: 7.806
# Iteration #3 - Objective function value:  0.05 - time: 8.846
# Iteration #4 - Objective function value:  0.05 - time: 8.892
# Iteration #5 - Objective function value:  0.05 - time: 7.944
# Iteration #6 - Objective function value:  0.05 - time: 8.848
# Iteration #7 - Objective function value:  0.05 - time: 8.771
# Iteration #8 - Objective function value:  0.05 - time: 8.251
# Iteration #9 - Objective function value:  0.05 - time: 8.654
# Iteration #10 - Objective function value:  0.05 - time: 8.866
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.4502471387386322
# repetition = 1
# Iteration #0 - Objective function value:  0.30 - time: 15.785
# Iteration #1 - Objective function value:  0.30 - time: 9.106
# Iteration #2 - Objective function value:  0.30 - time: 8.698
# Iteration #3 - Objective function value:  0.24 - time: 9.477
# Iteration #4 - Objective function value:  0.22 - time: 9.174
# Iteration #5 - Objective function value:  0.22 - time: 8.216
# Iteration #6 - Objective function value:  0.22 - time: 8.796
# Iteration #7 - Objective function value:  0.21 - time: 9.119
# Iteration #8 - Objective function value:  0.21 - time: 9.012
# Iteration #9 - Objective function value:  0.21 - time: 8.013
# Iteration #10 - Objective function value:  0.21 - time: 9.003
# Iteration #11 - Objective function value:  0.21 - time: 9.019
# Iteration #12 - Objective function value:  0.21 - time: 7.962
# Iteration #13 - Objective function value:  0.21 - time: 9.305
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.01329080294817686
# repetition = 2
# Iteration #0 - Objective function value:  0.05 - time: 13.912
# Iteration #1 - Objective function value:  0.05 - time: 8.985
# Iteration #2 - Objective function value:  0.05 - time: 8.562
# Iteration #3 - Objective function value:  0.05 - time: 8.712
# Iteration #4 - Objective function value:  0.05 - time: 9.078
# Iteration #5 - Objective function value:  0.05 - time: 9.107
# Iteration #6 - Objective function value:  0.05 - time: 7.919
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.49879366159439087
# repetition = 3
# Iteration #0 - Objective function value:  0.14 - time: 13.559
# Iteration #1 - Objective function value:  0.14 - time: 8.918
# Iteration #2 - Objective function value:  0.14 - time: 9.112
# Iteration #3 - Objective function value:  0.13 - time: 7.888
# Iteration #4 - Objective function value:  0.12 - time: 8.950
# Iteration #5 - Objective function value:  0.12 - time: 9.123
# Iteration #6 - Objective function value:  0.12 - time: 8.309
# Iteration #7 - Objective function value:  0.12 - time: 8.569
# Iteration #8 - Objective function value:  0.05 - time: 9.576
# Iteration #9 - Objective function value:  0.05 - time: 9.234
# Iteration #10 - Objective function value:  0.05 - time: 7.905
# Iteration #11 - Objective function value:  0.05 - time: 8.959
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.22728094458580017
# repetition = 4
# Iteration #0 - Objective function value:  0.17 - time: 13.881
# Iteration #1 - Objective function value:  0.17 - time: 8.845
# Iteration #2 - Objective function value:  0.17 - time: 8.212
# Iteration #3 - Objective function value:  0.17 - time: 8.849
# Iteration #4 - Objective function value:  0.16 - time: 9.000
# Iteration #5 - Objective function value:  0.16 - time: 8.832
# Iteration #6 - Objective function value:  0.16 - time: 8.367
# Iteration #7 - Objective function value:  0.16 - time: 9.253
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 1.156700611114502
# repetition = 5
# Iteration #0 - Objective function value:  0.08 - time: 13.797
# Iteration #1 - Objective function value:  0.07 - time: 9.343
# Iteration #2 - Objective function value:  0.07 - time: 8.008
# Iteration #3 - Objective function value:  0.07 - time: 9.198
# Iteration #4 - Objective function value:  0.07 - time: 9.382
# Iteration #5 - Objective function value:  0.07 - time: 8.947
# Iteration #6 - Objective function value:  0.06 - time: 8.264
# Iteration #7 - Objective function value:  0.06 - time: 9.090
# Iteration #8 - Objective function value:  0.06 - time: 9.185
# Iteration #9 - Objective function value:  0.06 - time: 7.971
# Iteration #10 - Objective function value:  0.06 - time: 9.138
# Iteration #11 - Objective function value:  0.06 - time: 9.178
# Iteration #12 - Objective function value:  0.06 - time: 7.961
# Iteration #13 - Objective function value:  0.06 - time: 9.594
# Iteration #14 - Objective function value:  0.06 - time: 9.168
# Iteration #15 - Objective function value:  0.06 - time: 9.230
# Iteration #16 - Objective function value:  0.06 - time: 8.144
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.7968387007713318
# repetition = 6
# Iteration #0 - Objective function value:  0.21 - time: 13.808
# Iteration #1 - Objective function value:  0.21 - time: 9.237
# Iteration #2 - Objective function value:  0.21 - time: 9.151
# Iteration #3 - Objective function value:  0.21 - time: 8.193
# Iteration #4 - Objective function value:  0.21 - time: 8.751
# Iteration #5 - Objective function value:  0.20 - time: 8.983
# Iteration #6 - Objective function value:  0.03 - time: 8.395
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Mean Squared Error on Test Set: 0.4340498447418213
# repetition = 7
# Iteration #0 - Objective function value:  0.12 - time: 13.735
# Iteration #1 - Objective function value:  0.12 - time: 7.948
# Iteration #2 - Objective function value:  0.12 - time: 8.920
# Iteration #3 - Objective function value:  0.12 - time: 9.070
# Iteration #4 - Objective function value:  0.12 - time: 7.950
# Iteration #5 - Objective function value:  0.12 - time: 9.158
# Iteration #6 - Objective function value:  0.11 - time: 9.022
# Iteration #7 - Objective function value:  0.11 - time: 7.988
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.10887186229228973
# repetition = 8
# Iteration #0 - Objective function value:  0.16 - time: 13.714
# Iteration #1 - Objective function value:  0.16 - time: 8.849
# Iteration #2 - Objective function value:  0.06 - time: 9.205
# Iteration #3 - Objective function value:  0.06 - time: 8.773
# Iteration #4 - Objective function value:  0.05 - time: 8.166
# Iteration #5 - Objective function value:  0.05 - time: 9.102
# Iteration #6 - Objective function value:  0.05 - time: 9.465
# Iteration #7 - Objective function value:  0.05 - time: 8.237
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.7168311476707458
# repetition = 9
# Iteration #0 - Objective function value:  0.10 - time: 14.125
# Iteration #1 - Objective function value:  0.09 - time: 8.795
# Iteration #2 - Objective function value:  0.09 - time: 9.163
# Iteration #3 - Objective function value:  0.09 - time: 9.159
# Iteration #4 - Objective function value:  0.09 - time: 8.103
# Iteration #5 - Objective function value:  0.09 - time: 8.987
# Iteration #6 - Objective function value:  0.09 - time: 8.945
# Iteration #7 - Objective function value:  0.09 - time: 8.030
# Iteration #8 - Objective function value:  0.09 - time: 9.006
# Iteration #9 - Objective function value:  0.09 - time: 9.112
# Iteration #10 - Objective function value:  0.09 - time: 7.955
# Iteration #11 - Objective function value:  0.09 - time: 8.990
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.5047112703323364
# repetition = 10
# Iteration #0 - Objective function value:  0.11 - time: 13.458
# Iteration #1 - Objective function value:  0.10 - time: 9.068
# Iteration #2 - Objective function value:  0.10 - time: 9.038
# Iteration #3 - Objective function value:  0.10 - time: 8.001
# Iteration #4 - Objective function value:  0.10 - time: 9.218
# Iteration #5 - Objective function value:  0.10 - time: 9.205
# Iteration #6 - Objective function value:  0.07 - time: 8.027
# Iteration #7 - Objective function value:  0.07 - time: 9.070
# Iteration #8 - Objective function value:  0.07 - time: 9.090
# Iteration #9 - Objective function value:  0.07 - time: 8.125
# Iteration #10 - Objective function value:  0.07 - time: 8.828
# Iteration #11 - Objective function value:  0.07 - time: 8.815
# Iteration #12 - Objective function value:  0.07 - time: 9.392
# Iteration #13 - Objective function value:  0.07 - time: 8.514
# Iteration #14 - Objective function value:  0.07 - time: 8.953
# Iteration #15 - Objective function value:  0.07 - time: 9.133
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.07442530989646912
# repetition = 11
# Iteration #0 - Objective function value:  0.36 - time: 13.696
# Iteration #1 - Objective function value:  0.34 - time: 8.163
# Iteration #2 - Objective function value:  0.33 - time: 8.828
# Iteration #3 - Objective function value:  0.33 - time: 9.160
# Iteration #4 - Objective function value:  0.31 - time: 9.067
# Iteration #5 - Objective function value:  0.31 - time: 8.607
# Iteration #6 - Objective function value:  0.31 - time: 9.127
# Iteration #7 - Objective function value:  0.31 - time: 8.969
# Iteration #8 - Objective function value:  0.31 - time: 8.160
# Iteration #9 - Objective function value:  0.31 - time: 8.894
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.7381171584129333
# repetition = 12
# Iteration #0 - Objective function value:  0.15 - time: 13.646
# Iteration #1 - Objective function value:  0.14 - time: 9.098
# Iteration #2 - Objective function value:  0.13 - time: 9.256
# Iteration #3 - Objective function value:  0.13 - time: 8.096
# Iteration #4 - Objective function value:  0.13 - time: 9.092
# Iteration #5 - Objective function value:  0.13 - time: 8.970
# Iteration #6 - Objective function value:  0.13 - time: 7.942
# Iteration #7 - Objective function value:  0.13 - time: 9.021
# Iteration #8 - Objective function value:  0.13 - time: 9.090
# Iteration #9 - Objective function value:  0.13 - time: 7.829
# Iteration #10 - Objective function value:  0.13 - time: 8.923
# Iteration #11 - Objective function value:  0.13 - time: 9.528
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.34575146436691284
# repetition = 13
# Iteration #0 - Objective function value:  0.03 - time: 13.850
# Iteration #1 - Objective function value:  0.03 - time: 9.343
# Iteration #2 - Objective function value:  0.03 - time: 8.303
# Iteration #3 - Objective function value:  0.03 - time: 10.208
# Iteration #4 - Objective function value:  0.03 - time: 9.101
# Iteration #5 - Objective function value:  0.03 - time: 8.858
# Iteration #6 - Objective function value:  0.03 - time: 8.198
# Iteration #7 - Objective function value:  0.03 - time: 9.124
# Iteration #8 - Objective function value:  0.03 - time: 9.229
# Iteration #9 - Objective function value:  0.03 - time: 8.117
# Iteration #10 - Objective function value:  0.03 - time: 9.190
# Iteration #11 - Objective function value:  0.03 - time: 9.051
# Iteration #12 - Objective function value:  0.03 - time: 8.152
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Mean Squared Error on Test Set: 0.3450072109699249
# repetition = 14
# Iteration #0 - Objective function value:  0.12 - time: 14.522
# Iteration #1 - Objective function value:  0.12 - time: 8.231
# Iteration #2 - Objective function value:  0.12 - time: 9.274
# Iteration #3 - Objective function value:  0.12 - time: 9.396
# Iteration #4 - Objective function value:  0.12 - time: 8.121
# Iteration #5 - Objective function value:  0.12 - time: 9.229
# Iteration #6 - Objective function value:  0.12 - time: 9.182
# Iteration #7 - Objective function value:  0.12 - time: 8.658
# Iteration #8 - Objective function value:  0.12 - time: 8.470
# Iteration #9 - Objective function value:  0.12 - time: 9.239
# Iteration #10 - Objective function value:  0.12 - time: 8.811
# Iteration #11 - Objective function value:  0.07 - time: 8.282
# Iteration #12 - Objective function value:  0.07 - time: 9.406
# Iteration #13 - Objective function value:  0.07 - time: 9.273
# Iteration #14 - Objective function value:  0.07 - time: 8.413
# Iteration #15 - Objective function value:  0.07 - time: 9.167
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.5899710059165955
# repetition = 15
# Iteration #0 - Objective function value:  0.08 - time: 13.981
# Iteration #1 - Objective function value:  0.07 - time: 8.985
# Iteration #2 - Objective function value:  0.07 - time: 9.269
# Iteration #3 - Objective function value:  0.07 - time: 8.101
# Iteration #4 - Objective function value:  0.07 - time: 9.174
# Iteration #5 - Objective function value:  0.07 - time: 8.993
# Iteration #6 - Objective function value:  0.07 - time: 8.196
# Iteration #7 - Objective function value:  0.07 - time: 8.976
# Iteration #8 - Objective function value:  0.06 - time: 9.203
# Iteration #9 - Objective function value:  0.06 - time: 8.849
# Iteration #10 - Objective function value:  0.06 - time: 8.416
# Iteration #11 - Objective function value:  0.06 - time: 9.011
# Iteration #12 - Objective function value:  0.06 - time: 9.067
# Iteration #13 - Objective function value:  0.06 - time: 8.206
# Iteration #14 - Objective function value:  0.06 - time: 9.104
# Iteration #15 - Objective function value:  0.06 - time: 9.167
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.06472492963075638
# repetition = 16
# Iteration #0 - Objective function value:  0.04 - time: 13.411
# Iteration #1 - Objective function value:  0.04 - time: 8.266
# Iteration #2 - Objective function value:  0.04 - time: 8.898
# Iteration #3 - Objective function value:  0.04 - time: 9.233
# Iteration #4 - Objective function value:  0.04 - time: 9.187
# Iteration #5 - Objective function value:  0.04 - time: 8.460
# Iteration #6 - Objective function value:  0.04 - time: 9.508
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.24180474877357483
# repetition = 17
# Iteration #0 - Objective function value:  0.11 - time: 14.063
# Iteration #1 - Objective function value:  0.11 - time: 9.249
# Iteration #2 - Objective function value:  0.10 - time: 9.184
# Iteration #3 - Objective function value:  0.10 - time: 8.087
# Iteration #4 - Objective function value:  0.10 - time: 9.064
# Iteration #5 - Objective function value:  0.10 - time: 9.111
# Iteration #6 - Objective function value:  0.10 - time: 8.161
# Iteration #7 - Objective function value:  0.10 - time: 9.034
# Iteration #8 - Objective function value:  0.10 - time: 9.129
# Iteration #9 - Objective function value:  0.10 - time: 8.472
# Iteration #10 - Objective function value:  0.10 - time: 8.784
# Iteration #11 - Objective function value:  0.10 - time: 9.017
# Iteration #12 - Objective function value:  0.10 - time: 9.274
# Iteration #13 - Objective function value:  0.10 - time: 7.905
# Iteration #14 - Objective function value:  0.10 - time: 9.098
# Iteration #15 - Objective function value:  0.10 - time: 9.128
# Iteration #16 - Objective function value:  0.10 - time: 8.102
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.17905858159065247
# repetition = 18
# Iteration #0 - Objective function value:  0.10 - time: 13.813
# Iteration #1 - Objective function value:  0.10 - time: 9.060
# Iteration #2 - Objective function value:  0.10 - time: 9.115
# Iteration #3 - Objective function value:  0.09 - time: 9.034
# Iteration #4 - Objective function value:  0.09 - time: 7.858
# Iteration #5 - Objective function value:  0.09 - time: 9.136
# Iteration #6 - Objective function value:  0.09 - time: 9.434
# Iteration #7 - Objective function value:  0.09 - time: 8.341
# Iteration #8 - Objective function value:  0.09 - time: 9.623
# Iteration #9 - Objective function value:  0.09 - time: 9.287
# Iteration #10 - Objective function value:  0.09 - time: 9.008
# Iteration #11 - Objective function value:  0.09 - time: 8.662
# Iteration #12 - Objective function value:  0.09 - time: 9.661
# Iteration #13 - Objective function value:  0.09 - time: 9.228
# Iteration #14 - Objective function value:  0.09 - time: 8.042
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.06418774276971817
# repetition = 19
# Iteration #0 - Objective function value:  0.20 - time: 14.204
# Iteration #1 - Objective function value:  0.20 - time: 8.834
# Iteration #2 - Objective function value:  0.20 - time: 9.074
# Iteration #3 - Objective function value:  0.19 - time: 9.077
# Iteration #4 - Objective function value:  0.18 - time: 8.079
# Iteration #5 - Objective function value:  0.18 - time: 9.185
# Iteration #6 - Objective function value:  0.18 - time: 9.179
# Iteration #7 - Objective function value:  0.18 - time: 8.141
# Iteration #8 - Objective function value:  0.18 - time: 8.975
# Iteration #9 - Objective function value:  0.18 - time: 9.014
# Iteration #10 - Objective function value:  0.18 - time: 8.116
# Iteration #11 - Objective function value:  0.14 - time: 8.879
# Iteration #12 - Objective function value:  0.14 - time: 8.952
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 1.1470273733139038
# repetition = 20
# Iteration #0 - Objective function value:  0.20 - time: 13.718
# Iteration #1 - Objective function value:  0.20 - time: 9.053
# Iteration #2 - Objective function value:  0.19 - time: 7.947
# Iteration #3 - Objective function value:  0.18 - time: 9.198
# Iteration #4 - Objective function value:  0.18 - time: 9.700
# Iteration #5 - Objective function value:  0.18 - time: 8.679
# Iteration #6 - Objective function value:  0.18 - time: 8.862
# Iteration #7 - Objective function value:  0.18 - time: 9.227
# Iteration #8 - Objective function value:  0.18 - time: 9.172
# Iteration #9 - Objective function value:  0.18 - time: 8.258
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 1.0805866718292236
# repetition = 21
# Iteration #0 - Objective function value:  0.19 - time: 13.809
# Iteration #1 - Objective function value:  0.19 - time: 9.269
# Iteration #2 - Objective function value:  0.18 - time: 9.307
# Iteration #3 - Objective function value:  0.18 - time: 8.985
# Iteration #4 - Objective function value:  0.18 - time: 8.233
# Iteration #5 - Objective function value:  0.18 - time: 9.140
# Iteration #6 - Objective function value:  0.17 - time: 9.375
# Iteration #7 - Objective function value:  0.17 - time: 7.936
# Iteration #8 - Objective function value:  0.17 - time: 9.154
# Iteration #9 - Objective function value:  0.17 - time: 9.395
# Iteration #10 - Objective function value:  0.17 - time: 8.161
# Iteration #11 - Objective function value:  0.17 - time: 9.230
# Iteration #12 - Objective function value:  0.17 - time: 9.577
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.002322286134585738
# repetition = 22
# Iteration #0 - Objective function value:  0.02 - time: 13.945
# Iteration #1 - Objective function value:  0.02 - time: 9.307
# Iteration #2 - Objective function value:  0.02 - time: 8.161
# Iteration #3 - Objective function value:  0.02 - time: 8.922
# Iteration #4 - Objective function value:  0.02 - time: 9.167
# Iteration #5 - Objective function value:  0.02 - time: 8.899
# Iteration #6 - Objective function value:  0.02 - time: 8.868
# Iteration #7 - Objective function value:  0.02 - time: 9.531
# Iteration #8 - Objective function value:  0.02 - time: 9.469
# Iteration #9 - Objective function value:  0.02 - time: 8.368
# Iteration #10 - Objective function value:  0.02 - time: 9.298
# Iteration #11 - Objective function value:  0.02 - time: 9.286
# Iteration #12 - Objective function value:  0.02 - time: 9.313
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.419761061668396
# repetition = 23
# Iteration #0 - Objective function value:  0.16 - time: 13.989
# Iteration #1 - Objective function value:  0.15 - time: 8.208
# Iteration #2 - Objective function value:  0.15 - time: 9.190
# Iteration #3 - Objective function value:  0.15 - time: 9.108
# Iteration #4 - Objective function value:  0.15 - time: 8.573
# Iteration #5 - Objective function value:  0.15 - time: 8.707
# Iteration #6 - Objective function value:  0.15 - time: 9.313
# Iteration #7 - Objective function value:  0.15 - time: 9.253
# Iteration #8 - Objective function value:  0.15 - time: 8.154
# Iteration #9 - Objective function value:  0.15 - time: 9.292
# Iteration #10 - Objective function value:  0.15 - time: 9.172
# Iteration #11 - Objective function value:  0.15 - time: 8.448
# Iteration #12 - Objective function value:  0.15 - time: 9.521
# Iteration #13 - Objective function value:  0.15 - time: 9.247
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.31584984064102173
# repetition = 24
# Iteration #0 - Objective function value:  0.20 - time: 13.773
# Iteration #1 - Objective function value:  0.19 - time: 9.162
# Iteration #2 - Objective function value:  0.18 - time: 8.344
# Iteration #3 - Objective function value:  0.18 - time: 9.070
# Iteration #4 - Objective function value:  0.18 - time: 9.256
# Iteration #5 - Objective function value:  0.18 - time: 9.889
# Iteration #6 - Objective function value:  0.17 - time: 8.686
# Iteration #7 - Objective function value:  0.17 - time: 9.451
# Iteration #8 - Objective function value:  0.17 - time: 9.269
# Iteration #9 - Objective function value:  0.17 - time: 8.642
# Iteration #10 - Objective function value:  0.17 - time: 8.853
# Iteration #11 - Objective function value:  0.17 - time: 9.130
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 1.112240195274353
# repetition = 25
# Iteration #0 - Objective function value:  0.17 - time: 13.979
# Iteration #1 - Objective function value:  0.17 - time: 9.285
# Iteration #2 - Objective function value:  0.17 - time: 8.340
# Iteration #3 - Objective function value:  0.17 - time: 8.816
# Iteration #4 - Objective function value:  0.16 - time: 9.009
# Iteration #5 - Objective function value:  0.16 - time: 9.078
# Iteration #6 - Objective function value:  0.16 - time: 8.213
# Iteration #7 - Objective function value:  0.16 - time: 9.207
# Iteration #8 - Objective function value:  0.16 - time: 9.284
# Iteration #9 - Objective function value:  0.16 - time: 8.187
# Iteration #10 - Objective function value:  0.10 - time: 9.044
# Iteration #11 - Objective function value:  0.09 - time: 8.942
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.07628671824932098
# repetition = 26
# Iteration #0 - Objective function value:  0.20 - time: 13.637
# Iteration #1 - Objective function value:  0.19 - time: 8.872
# Iteration #2 - Objective function value:  0.19 - time: 8.204
# Iteration #3 - Objective function value:  0.19 - time: 9.128
# Iteration #4 - Objective function value:  0.19 - time: 9.077
# Iteration #5 - Objective function value:  0.19 - time: 8.045
# Iteration #6 - Objective function value:  0.19 - time: 9.864
# Iteration #7 - Objective function value:  0.19 - time: 9.470
# Iteration #8 - Objective function value:  0.19 - time: 9.208
# Iteration #9 - Objective function value:  0.14 - time: 8.742
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.135520800948143
# repetition = 27
# Iteration #0 - Objective function value:  0.09 - time: 13.939
# Iteration #1 - Objective function value:  0.08 - time: 9.328
# Iteration #2 - Objective function value:  0.08 - time: 9.220
# Iteration #3 - Objective function value:  0.08 - time: 8.863
# Iteration #4 - Objective function value:  0.08 - time: 9.088
# Iteration #5 - Objective function value:  0.08 - time: 9.419
# Iteration #6 - Objective function value:  0.08 - time: 9.293
# Iteration #7 - Objective function value:  0.08 - time: 8.486
# Iteration #8 - Objective function value:  0.08 - time: 9.460
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.038929570466279984
# repetition = 28
# Iteration #0 - Objective function value:  0.26 - time: 13.956
# Iteration #1 - Objective function value:  0.25 - time: 9.067
# Iteration #2 - Objective function value:  0.24 - time: 9.312
# Iteration #3 - Objective function value:  0.24 - time: 8.235
# Iteration #4 - Objective function value:  0.24 - time: 9.170
# Iteration #5 - Objective function value:  0.24 - time: 9.326
# Iteration #6 - Objective function value:  0.24 - time: 8.559
# Iteration #7 - Objective function value:  0.24 - time: 8.813
# Iteration #8 - Objective function value:  0.24 - time: 9.243
# Iteration #9 - Objective function value:  0.06 - time: 9.216
# Iteration #10 - Objective function value:  0.06 - time: 8.090
# Iteration #11 - Objective function value:  0.06 - time: 9.168
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.678838312625885
# repetition = 29
# Iteration #0 - Objective function value:  0.08 - time: 14.019
# Iteration #1 - Objective function value:  0.07 - time: 9.529
# Iteration #2 - Objective function value:  0.07 - time: 9.481
# Iteration #3 - Objective function value:  0.07 - time: 8.455
# Iteration #4 - Objective function value:  0.07 - time: 9.578
# Iteration #5 - Objective function value:  0.07 - time: 9.502
# Iteration #6 - Objective function value:  0.07 - time: 9.589
# Iteration #7 - Objective function value:  0.07 - time: 8.520
# Iteration #8 - Objective function value:  0.07 - time: 9.402
# Iteration #9 - Objective function value:  0.07 - time: 9.588
# Iteration #10 - Objective function value:  0.07 - time: 8.411
# Iteration #11 - Objective function value:  0.07 - time: 9.302
# Iteration #12 - Objective function value:  0.07 - time: 9.283
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.16230180859565735
# repetition = 30
# Iteration #0 - Objective function value:  0.08 - time: 13.709
# Iteration #1 - Objective function value:  0.08 - time: 9.169
# Iteration #2 - Objective function value:  0.08 - time: 8.163
# Iteration #3 - Objective function value:  0.08 - time: 9.369
# Iteration #4 - Objective function value:  0.08 - time: 9.281
# Iteration #5 - Objective function value:  0.08 - time: 8.440
# Iteration #6 - Objective function value:  0.08 - time: 8.880
# Iteration #7 - Objective function value:  0.08 - time: 9.503
# Iteration #8 - Objective function value:  0.08 - time: 9.122
# Iteration #9 - Objective function value:  0.08 - time: 7.996
# Iteration #10 - Objective function value:  0.08 - time: 9.107
# Iteration #11 - Objective function value:  0.08 - time: 8.935
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.2891676425933838
# repetition = 31
# Iteration #0 - Objective function value:  0.07 - time: 14.137
# Iteration #1 - Objective function value:  0.07 - time: 8.980
# Iteration #2 - Objective function value:  0.07 - time: 8.912
# Iteration #3 - Objective function value:  0.07 - time: 9.534
# Iteration #4 - Objective function value:  0.07 - time: 9.425
# Iteration #5 - Objective function value:  0.07 - time: 8.216
# Iteration #6 - Objective function value:  0.07 - time: 9.609
# Iteration #7 - Objective function value:  0.07 - time: 9.387
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.5832535028457642
# repetition = 32
# Iteration #0 - Objective function value:  0.03 - time: 14.086
# Iteration #1 - Objective function value:  0.03 - time: 9.496
# Iteration #2 - Objective function value:  0.03 - time: 8.281
# Iteration #3 - Objective function value:  0.03 - time: 9.117
# Iteration #4 - Objective function value:  0.03 - time: 9.462
# Iteration #5 - Objective function value:  0.03 - time: 9.325
# Iteration #6 - Objective function value:  0.03 - time: 8.099
# Iteration #7 - Objective function value:  0.03 - time: 9.104
# Iteration #8 - Objective function value:  0.03 - time: 9.203
# Iteration #9 - Objective function value:  0.03 - time: 8.001
# Iteration #10 - Objective function value:  0.03 - time: 9.201
# Iteration #11 - Objective function value:  0.03 - time: 9.147
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.3584645092487335
# repetition = 33
# Iteration #0 - Objective function value:  0.13 - time: 13.722
# Iteration #1 - Objective function value:  0.13 - time: 9.463
# Iteration #2 - Objective function value:  0.13 - time: 8.161
# Iteration #3 - Objective function value:  0.13 - time: 9.083
# Iteration #4 - Objective function value:  0.13 - time: 8.981
# Iteration #5 - Objective function value:  0.13 - time: 8.211
# Iteration #6 - Objective function value:  0.13 - time: 9.707
# Iteration #7 - Objective function value:  0.13 - time: 9.551
# Iteration #8 - Objective function value:  0.13 - time: 9.642
# Iteration #9 - Objective function value:  0.13 - time: 8.907
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.4915105998516083
# repetition = 34
# Iteration #0 - Objective function value:  0.24 - time: 15.315
# Iteration #1 - Objective function value:  0.23 - time: 8.739
# Iteration #2 - Objective function value:  0.23 - time: 9.532
# Iteration #3 - Objective function value:  0.22 - time: 9.610
# Iteration #4 - Objective function value:  0.22 - time: 8.552
# Iteration #5 - Objective function value:  0.22 - time: 8.845
# Iteration #6 - Objective function value:  0.22 - time: 9.013
# Iteration #7 - Objective function value:  0.22 - time: 9.255
# Iteration #8 - Objective function value:  0.22 - time: 8.333
# Iteration #9 - Objective function value:  0.22 - time: 9.197
# Iteration #10 - Objective function value:  0.22 - time: 9.140
# Iteration #11 - Objective function value:  0.22 - time: 7.977
# Iteration #12 - Objective function value:  0.22 - time: 9.215
# Iteration #13 - Objective function value:  0.22 - time: 9.373
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.07695547491312027
# repetition = 35
# Iteration #0 - Objective function value:  0.18 - time: 14.328
# Iteration #1 - Objective function value:  0.17 - time: 9.269
# Iteration #2 - Objective function value:  0.16 - time: 8.163
# Iteration #3 - Objective function value:  0.15 - time: 9.442
# Iteration #4 - Objective function value:  0.15 - time: 9.275
# Iteration #5 - Objective function value:  0.15 - time: 8.343
# Iteration #6 - Objective function value:  0.15 - time: 8.858
# Iteration #7 - Objective function value:  0.15 - time: 9.596
# Iteration #8 - Objective function value:  0.15 - time: 9.690
# Iteration #9 - Objective function value:  0.10 - time: 8.489
# Iteration #10 - Objective function value:  0.09 - time: 9.636
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.0495368093252182
# repetition = 36
# Iteration #0 - Objective function value:  0.12 - time: 14.393
# Iteration #1 - Objective function value:  0.11 - time: 9.633
# Iteration #2 - Objective function value:  0.11 - time: 9.479
# Iteration #3 - Objective function value:  0.11 - time: 8.610
# Iteration #4 - Objective function value:  0.11 - time: 9.084
# Iteration #5 - Objective function value:  0.11 - time: 9.272
# Iteration #6 - Objective function value:  0.11 - time: 9.500
# Iteration #7 - Objective function value:  0.11 - time: 8.523
# Iteration #8 - Objective function value:  0.11 - time: 9.405
# Iteration #9 - Objective function value:  0.11 - time: 9.129
# Iteration #10 - Objective function value:  0.11 - time: 8.717
# Iteration #11 - Objective function value:  0.11 - time: 8.911
# Iteration #12 - Objective function value:  0.11 - time: 9.208
# Iteration #13 - Objective function value:  0.11 - time: 9.333
# Iteration #14 - Objective function value:  0.11 - time: 8.429
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.13295969367027283
# repetition = 37
# Iteration #0 - Objective function value:  0.08 - time: 14.041
# Iteration #1 - Objective function value:  0.08 - time: 9.027
# Iteration #2 - Objective function value:  0.08 - time: 9.359
# Iteration #3 - Objective function value:  0.08 - time: 9.232
# Iteration #4 - Objective function value:  0.08 - time: 8.215
# Iteration #5 - Objective function value:  0.08 - time: 9.085
# Iteration #6 - Objective function value:  0.08 - time: 9.127
# Iteration #7 - Objective function value:  0.08 - time: 8.658
# Iteration #8 - Objective function value:  0.08 - time: 9.451
# Iteration #9 - Objective function value:  0.08 - time: 9.431
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.8442437052726746
# repetition = 38
# Iteration #0 - Objective function value:  0.01 - time: 14.303
# Iteration #1 - Objective function value:  0.01 - time: 9.306
# Iteration #2 - Objective function value:  0.01 - time: 8.772
# Iteration #3 - Objective function value:  0.01 - time: 9.118
# Iteration #4 - Objective function value:  0.01 - time: 9.276
# Iteration #5 - Objective function value:  0.01 - time: 9.476
# Iteration #6 - Objective function value:  0.01 - time: 8.166
# Iteration #7 - Objective function value:  0.01 - time: 9.229
# Iteration #8 - Objective function value:  0.01 - time: 9.287
# Iteration #9 - Objective function value:  0.01 - time: 8.765
# Iteration #10 - Objective function value:  0.01 - time: 8.767
# Iteration #11 - Objective function value:  0.01 - time: 9.153
# Iteration #12 - Objective function value:  0.01 - time: 9.218
# Iteration #13 - Objective function value:  0.01 - time: 8.209
# Iteration #14 - Objective function value:  0.01 - time: 9.154
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.28260910511016846
# repetition = 39
# Iteration #0 - Objective function value:  0.13 - time: 13.965
# Iteration #1 - Objective function value:  0.13 - time: 9.284
# Iteration #2 - Objective function value:  0.13 - time: 8.993
# Iteration #3 - Objective function value:  0.12 - time: 8.303
# Iteration #4 - Objective function value:  0.12 - time: 9.064
# Iteration #5 - Objective function value:  0.12 - time: 9.235
# Iteration #6 - Objective function value:  0.12 - time: 8.144
# Iteration #7 - Objective function value:  0.12 - time: 9.430
# Iteration #8 - Objective function value:  0.11 - time: 9.427
# Iteration #9 - Objective function value:  0.11 - time: 9.617
# Iteration #10 - Objective function value:  0.11 - time: 8.495
# Iteration #11 - Objective function value:  0.11 - time: 9.584
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.2186635136604309
# repetition = 40
# Iteration #0 - Objective function value:  0.04 - time: 14.119
# Iteration #1 - Objective function value:  0.04 - time: 9.580
# Iteration #2 - Objective function value:  0.04 - time: 9.404
# Iteration #3 - Objective function value:  0.04 - time: 8.189
# Iteration #4 - Objective function value:  0.04 - time: 9.322
# Iteration #5 - Objective function value:  0.04 - time: 9.251
# Iteration #6 - Objective function value:  0.04 - time: 8.203
# Iteration #7 - Objective function value:  0.04 - time: 8.845
# Iteration #8 - Objective function value:  0.04 - time: 9.126
# Iteration #9 - Objective function value:  0.04 - time: 8.959
# Iteration #10 - Objective function value:  0.04 - time: 8.403
# Iteration #11 - Objective function value:  0.04 - time: 9.164
# Iteration #12 - Objective function value:  0.04 - time: 9.225
# Iteration #13 - Objective function value:  0.04 - time: 8.182
# Iteration #14 - Objective function value:  0.04 - time: 9.053
# Iteration #15 - Objective function value:  0.04 - time: 9.118
# Iteration #16 - Objective function value:  0.04 - time: 8.307
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Mean Squared Error on Test Set: 0.17206542193889618
# repetition = 41
# Iteration #0 - Objective function value:  0.12 - time: 14.342
# Iteration #1 - Objective function value:  0.11 - time: 8.108
# Iteration #2 - Objective function value:  0.11 - time: 9.054
# Iteration #3 - Objective function value:  0.11 - time: 9.250
# Iteration #4 - Objective function value:  0.11 - time: 8.482
# Iteration #5 - Objective function value:  0.11 - time: 9.511
# Iteration #6 - Objective function value:  0.11 - time: 9.420
# Iteration #7 - Objective function value:  0.07 - time: 9.594
# Iteration #8 - Objective function value:  0.07 - time: 8.456
# Iteration #9 - Objective function value:  0.07 - time: 9.492
# Iteration #10 - Objective function value:  0.07 - time: 9.599
# Iteration #11 - Objective function value:  0.07 - time: 9.109
# Iteration #12 - Objective function value:  0.06 - time: 8.522
# Iteration #13 - Objective function value:  0.06 - time: 9.324
# Iteration #14 - Objective function value:  0.06 - time: 9.319
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.22122086584568024
# repetition = 42
# Iteration #0 - Objective function value:  0.15 - time: 13.833
# Iteration #1 - Objective function value:  0.15 - time: 9.037
# Iteration #2 - Objective function value:  0.15 - time: 8.776
# Iteration #3 - Objective function value:  0.15 - time: 9.325
# Iteration #4 - Objective function value:  0.15 - time: 9.398
# Iteration #5 - Objective function value:  0.15 - time: 8.235
# Iteration #6 - Objective function value:  0.15 - time: 9.325
# Iteration #7 - Objective function value:  0.15 - time: 9.415
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.7009668350219727
# repetition = 43
# Iteration #0 - Objective function value:  0.06 - time: 14.035
# Iteration #1 - Objective function value:  0.06 - time: 9.360
# Iteration #2 - Objective function value:  0.05 - time: 8.301
# Iteration #3 - Objective function value:  0.05 - time: 9.367
# Iteration #4 - Objective function value:  0.05 - time: 9.301
# Iteration #5 - Objective function value:  0.05 - time: 8.871
# Iteration #6 - Objective function value:  0.05 - time: 8.900
# Iteration #7 - Objective function value:  0.05 - time: 9.342
# Iteration #8 - Objective function value:  0.05 - time: 9.629
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.18050818145275116
# repetition = 44
# Iteration #0 - Objective function value:  0.07 - time: 14.393
# Iteration #1 - Objective function value:  0.07 - time: 9.537
# Iteration #2 - Objective function value:  0.05 - time: 8.506
# Iteration #3 - Objective function value:  0.05 - time: 9.547
# Iteration #4 - Objective function value:  0.05 - time: 9.485
# Iteration #5 - Objective function value:  0.05 - time: 9.034
# Iteration #6 - Objective function value:  0.05 - time: 8.909
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Mean Squared Error on Test Set: 0.11375473439693451
# repetition = 45
# Iteration #0 - Objective function value:  0.11 - time: 14.112
# Iteration #1 - Objective function value:  0.10 - time: 9.582
# Iteration #2 - Objective function value:  0.10 - time: 9.419
# Iteration #3 - Objective function value:  0.10 - time: 8.745
# Iteration #4 - Objective function value:  0.10 - time: 8.641
# Iteration #5 - Objective function value:  0.10 - time: 9.224
# Iteration #6 - Objective function value:  0.09 - time: 9.256
# Iteration #7 - Objective function value:  0.09 - time: 8.099
# Iteration #8 - Objective function value:  0.09 - time: 9.868
# Iteration #9 - Objective function value:  0.09 - time: 9.656
# Iteration #10 - Objective function value:  0.09 - time: 9.044
# Iteration #11 - Objective function value:  0.09 - time: 8.822
# Iteration #12 - Objective function value:  0.09 - time: 9.359
# Iteration #13 - Objective function value:  0.09 - time: 9.160
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.5313073396682739
# repetition = 46
# Iteration #0 - Objective function value:  0.20 - time: 13.763
# Iteration #1 - Objective function value:  0.20 - time: 8.942
# Iteration #2 - Objective function value:  0.20 - time: 9.125
# Iteration #3 - Objective function value:  0.20 - time: 9.606
# Iteration #4 - Objective function value:  0.20 - time: 9.691
# Iteration #5 - Objective function value:  0.19 - time: 8.652
# Iteration #6 - Objective function value:  0.19 - time: 9.476
# Iteration #7 - Objective function value:  0.19 - time: 9.702
# Iteration #8 - Objective function value:  0.19 - time: 9.555
# Iteration #9 - Objective function value:  0.19 - time: 8.523
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 1.4060128927230835
# repetition = 47
# Iteration #0 - Objective function value:  0.06 - time: 14.225
# Iteration #1 - Objective function value:  0.06 - time: 8.742
# Iteration #2 - Objective function value:  0.05 - time: 9.292
# Iteration #3 - Objective function value:  0.05 - time: 9.213
# Iteration #4 - Objective function value:  0.05 - time: 8.178
# Iteration #5 - Objective function value:  0.05 - time: 9.236
# Iteration #6 - Objective function value:  0.05 - time: 9.393
# Iteration #7 - Objective function value:  0.05 - time: 8.359
# Iteration #8 - Objective function value:  0.05 - time: 8.926
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.6735770106315613
# repetition = 48
# Iteration #0 - Objective function value:  0.17 - time: 13.985
# Iteration #1 - Objective function value:  0.15 - time: 9.211
# Iteration #2 - Objective function value:  0.15 - time: 9.402
# Iteration #3 - Objective function value:  0.13 - time: 8.367
# Iteration #4 - Objective function value:  0.13 - time: 9.220
# Iteration #5 - Objective function value:  0.13 - time: 9.034
# Iteration #6 - Objective function value:  0.13 - time: 9.377
# Iteration #7 - Objective function value:  0.13 - time: 8.134
# Iteration #8 - Objective function value:  0.13 - time: 9.682
# Iteration #9 - Objective function value:  0.13 - time: 9.583
# Iteration #10 - Objective function value:  0.13 - time: 9.016
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Mean Squared Error on Test Set: 0.14645715057849884
# repetition = 49
# Iteration #0 - Objective function value:  0.14 - time: 14.898
# Iteration #1 - Objective function value:  0.14 - time: 8.460
# Iteration #2 - Objective function value:  0.14 - time: 9.341
# Iteration #3 - Objective function value:  0.14 - time: 9.437
# Iteration #4 - Objective function value:  0.13 - time: 9.298
# Iteration #5 - Objective function value:  0.13 - time: 8.416
# Iteration #6 - Objective function value:  0.13 - time: 9.500
# Iteration #7 - Objective function value:  0.13 - time: 9.391
# Iteration #8 - Objective function value:  0.13 - time: 8.203
# Iteration #9 - Objective function value:  0.13 - time: 9.653
# Iteration #10 - Objective function value:  0.13 - time: 9.052
# Iteration #11 - Objective function value:  0.13 - time: 9.240
# Iteration #12 - Objective function value:  0.13 - time: 8.362
# Iteration #13 - Objective function value:  0.13 - time: 9.273
# Iteration #14 - Objective function value:  0.13 - time: 9.336
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.4069466292858124
# repetition = 50
# Iteration #0 - Objective function value:  0.18 - time: 13.810
# Iteration #1 - Objective function value:  0.17 - time: 9.002
# Iteration #2 - Objective function value:  0.16 - time: 8.407
# Iteration #3 - Objective function value:  0.16 - time: 9.175
# Iteration #4 - Objective function value:  0.16 - time: 9.313
# Iteration #5 - Objective function value:  0.16 - time: 8.138
# Iteration #6 - Objective function value:  0.16 - time: 9.342
# Iteration #7 - Objective function value:  0.16 - time: 9.783
# Iteration #8 - Objective function value:  0.15 - time: 9.686
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.19814032316207886
# repetition = 51
# Iteration #0 - Objective function value:  0.20 - time: 15.225
# Iteration #1 - Objective function value:  0.20 - time: 9.854
# Iteration #2 - Objective function value:  0.20 - time: 9.095
# Iteration #3 - Objective function value:  0.20 - time: 9.748
# Iteration #4 - Objective function value:  0.20 - time: 9.802
# Iteration #5 - Objective function value:  0.20 - time: 9.569
# Iteration #6 - Objective function value:  0.20 - time: 8.673
# Iteration #7 - Objective function value:  0.20 - time: 9.530
# Iteration #8 - Objective function value:  0.19 - time: 9.469
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.53792405128479
# repetition = 52
# Iteration #0 - Objective function value:  0.34 - time: 14.244
# Iteration #1 - Objective function value:  0.34 - time: 9.367
# Iteration #2 - Objective function value:  0.34 - time: 8.453
# Iteration #3 - Objective function value:  0.22 - time: 9.487
# Iteration #4 - Objective function value:  0.22 - time: 9.547
# Iteration #5 - Objective function value:  0.22 - time: 9.876
# Iteration #6 - Objective function value:  0.22 - time: 8.560
# Iteration #7 - Objective function value:  0.22 - time: 9.421
# Iteration #8 - Objective function value:  0.21 - time: 9.297
# Iteration #9 - Objective function value:  0.21 - time: 8.876
# Iteration #10 - Objective function value:  0.21 - time: 8.727
# Iteration #11 - Objective function value:  0.21 - time: 9.149
# Iteration #12 - Objective function value:  0.21 - time: 9.245
# Iteration #13 - Objective function value:  0.21 - time: 8.376
# Iteration #14 - Objective function value:  0.21 - time: 9.367
# Iteration #15 - Objective function value:  0.21 - time: 10.050
# Iteration #16 - Objective function value:  0.20 - time: 9.799
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.13540586829185486
# repetition = 53
# Iteration #0 - Objective function value:  0.33 - time: 14.747
# Iteration #1 - Objective function value:  0.30 - time: 9.677
# Iteration #2 - Objective function value:  0.30 - time: 8.888
# Iteration #3 - Objective function value:  0.30 - time: 10.183
# Iteration #4 - Objective function value:  0.30 - time: 9.866
# Iteration #5 - Objective function value:  0.30 - time: 9.686
# Iteration #6 - Objective function value:  0.30 - time: 8.592
# Iteration #7 - Objective function value:  0.29 - time: 10.461
# Iteration #8 - Objective function value:  0.29 - time: 9.940
# Iteration #9 - Objective function value:  0.29 - time: 9.383
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Mean Squared Error on Test Set: 0.11127886921167374
# repetition = 54
# Iteration #0 - Objective function value:  0.07 - time: 14.298
# Iteration #1 - Objective function value:  0.06 - time: 9.659
# Iteration #2 - Objective function value:  0.06 - time: 8.539
# Iteration #3 - Objective function value:  0.06 - time: 9.677
# Iteration #4 - Objective function value:  0.06 - time: 9.603
# Iteration #5 - Objective function value:  0.06 - time: 9.169
# Iteration #6 - Objective function value:  0.06 - time: 8.970
# Iteration #7 - Objective function value:  0.06 - time: 9.450
# Iteration #8 - Objective function value:  0.06 - time: 9.286
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.2468259334564209
# repetition = 55
# Iteration #0 - Objective function value:  0.08 - time: 13.975
# Iteration #1 - Objective function value:  0.08 - time: 8.826
# Iteration #2 - Objective function value:  0.08 - time: 8.659
# Iteration #3 - Objective function value:  0.06 - time: 9.464
# Iteration #4 - Objective function value:  0.06 - time: 10.029
# Iteration #5 - Objective function value:  0.06 - time: 8.972
# Iteration #6 - Objective function value:  0.06 - time: 9.454
# Iteration #7 - Objective function value:  0.06 - time: 9.532
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.1474500596523285
# repetition = 56
# Iteration #0 - Objective function value:  0.07 - time: 14.346
# Iteration #1 - Objective function value:  0.07 - time: 9.627
# Iteration #2 - Objective function value:  0.07 - time: 9.551
# Iteration #3 - Objective function value:  0.06 - time: 8.175
# Iteration #4 - Objective function value:  0.06 - time: 9.507
# Iteration #5 - Objective function value:  0.06 - time: 9.429
# Iteration #6 - Objective function value:  0.06 - time: 8.195
# Iteration #7 - Objective function value:  0.06 - time: 9.268
# Iteration #8 - Objective function value:  0.06 - time: 9.270
# Iteration #9 - Objective function value:  0.06 - time: 9.256
# ...
# Iteration #8 - Objective function value:  0.06 - time: 9.614
# Iteration #9 - Objective function value:  0.06 - time: 8.297
# Iteration #10 - Objective function value:  0.06 - time: 9.415
# Iteration #11 - Objective function value:  0.06 - time: 9.132
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.10881690680980682
# repetition = 85
# Iteration #0 - Objective function value:  0.17 - time: 14.785
# Iteration #1 - Objective function value:  0.17 - time: 9.679
# Iteration #2 - Objective function value:  0.17 - time: 8.545
# Iteration #3 - Objective function value:  0.17 - time: 9.440
# Iteration #4 - Objective function value:  0.17 - time: 9.428
# Iteration #5 - Objective function value:  0.16 - time: 9.516
# Iteration #6 - Objective function value:  0.16 - time: 8.404
# Iteration #7 - Objective function value:  0.16 - time: 9.511
# Iteration #8 - Objective function value:  0.16 - time: 9.554
# Iteration #9 - Objective function value:  0.16 - time: 8.589
# Iteration #10 - Objective function value:  0.16 - time: 9.142
# Iteration #11 - Objective function value:  0.16 - time: 9.157
# Iteration #12 - Objective function value:  0.16 - time: 9.266
# Iteration #13 - Objective function value:  0.16 - time: 8.133
# Iteration #14 - Objective function value:  0.16 - time: 9.229
# Iteration #15 - Objective function value:  0.16 - time: 9.108
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.733739972114563
# repetition = 86
# Iteration #0 - Objective function value:  0.06 - time: 13.723
# Iteration #1 - Objective function value:  0.06 - time: 9.056
# Iteration #2 - Objective function value:  0.06 - time: 8.363
# Iteration #3 - Objective function value:  0.06 - time: 9.273
# Iteration #4 - Objective function value:  0.06 - time: 9.281
# Iteration #5 - Objective function value:  0.06 - time: 8.147
# Iteration #6 - Objective function value:  0.06 - time: 9.293
# Iteration #7 - Objective function value:  0.06 - time: 9.302
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.5092599391937256
# repetition = 87
# Iteration #0 - Objective function value:  0.21 - time: 13.831
# Iteration #1 - Objective function value:  0.21 - time: 9.780
# Iteration #2 - Objective function value:  0.21 - time: 8.709
# Iteration #3 - Objective function value:  0.19 - time: 9.656
# Iteration #4 - Objective function value:  0.19 - time: 9.825
# Iteration #5 - Objective function value:  0.19 - time: 9.706
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 1.0311198234558105
# repetition = 88
# Iteration #0 - Objective function value:  0.10 - time: 14.354
# Iteration #1 - Objective function value:  0.10 - time: 9.371
# Iteration #2 - Objective function value:  0.10 - time: 8.451
# Iteration #3 - Objective function value:  0.09 - time: 9.390
# Iteration #4 - Objective function value:  0.09 - time: 9.504
# Iteration #5 - Objective function value:  0.09 - time: 8.291
# Iteration #6 - Objective function value:  0.09 - time: 9.160
# Iteration #7 - Objective function value:  0.09 - time: 9.362
# Iteration #8 - Objective function value:  0.09 - time: 8.911
# Iteration #9 - Objective function value:  0.09 - time: 8.529
# Iteration #10 - Objective function value:  0.09 - time: 9.289
# Iteration #11 - Objective function value:  0.09 - time: 9.205
# Iteration #12 - Objective function value:  0.09 - time: 8.180
# Iteration #13 - Objective function value:  0.09 - time: 9.305
# Iteration #14 - Objective function value:  0.09 - time: 9.493
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.039316706359386444
# repetition = 89
# Iteration #0 - Objective function value:  0.17 - time: 13.757
# Iteration #1 - Objective function value:  0.17 - time: 9.089
# Iteration #2 - Objective function value:  0.16 - time: 8.282
# Iteration #3 - Objective function value:  0.16 - time: 9.272
# Iteration #4 - Objective function value:  0.16 - time: 9.226
# Iteration #5 - Objective function value:  0.16 - time: 8.826
# Iteration #6 - Objective function value:  0.16 - time: 9.119
# Iteration #7 - Objective function value:  0.16 - time: 9.610
# Iteration #8 - Objective function value:  0.16 - time: 9.577
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.2964541018009186
# repetition = 90
# Iteration #0 - Objective function value:  0.21 - time: 14.246
# Iteration #1 - Objective function value:  0.21 - time: 9.494
# Iteration #2 - Objective function value:  0.20 - time: 8.550
# Iteration #3 - Objective function value:  0.20 - time: 9.482
# Iteration #4 - Objective function value:  0.20 - time: 9.293
# Iteration #5 - Objective function value:  0.20 - time: 8.571
# Iteration #6 - Objective function value:  0.20 - time: 9.411
# Iteration #7 - Objective function value:  0.20 - time: 9.568
# Iteration #8 - Objective function value:  0.19 - time: 9.466
# Iteration #9 - Objective function value:  0.19 - time: 9.531
# Iteration #10 - Objective function value:  0.19 - time: 9.056
# Iteration #11 - Objective function value:  0.19 - time: 9.364
# Iteration #12 - Objective function value:  0.19 - time: 9.533
# Iteration #13 - Objective function value:  0.19 - time: 8.247
# Iteration #14 - Objective function value:  0.19 - time: 9.441
# Iteration #15 - Objective function value:  0.18 - time: 9.327
# Iteration #16 - Objective function value:  0.16 - time: 8.666
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Mean Squared Error on Test Set: 0.39306291937828064
# repetition = 91
# Iteration #0 - Objective function value:  0.22 - time: 14.310
# Iteration #1 - Objective function value:  0.22 - time: 8.409
# Iteration #2 - Objective function value:  0.21 - time: 9.236
# Iteration #3 - Objective function value:  0.21 - time: 9.362
# Iteration #4 - Objective function value:  0.21 - time: 8.184
# Iteration #5 - Objective function value:  0.21 - time: 9.609
# Iteration #6 - Objective function value:  0.21 - time: 9.712
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.3819745182991028
# repetition = 92
# Iteration #0 - Objective function value:  0.15 - time: 14.386
# Iteration #1 - Objective function value:  0.15 - time: 9.509
# Iteration #2 - Objective function value:  0.14 - time: 9.554
# Iteration #3 - Objective function value:  0.14 - time: 8.312
# Iteration #4 - Objective function value:  0.14 - time: 9.361
# Iteration #5 - Objective function value:  0.14 - time: 9.384
# Iteration #6 - Objective function value:  0.14 - time: 8.874
# Iteration #7 - Objective function value:  0.14 - time: 9.099
# Iteration #8 - Objective function value:  0.14 - time: 9.582
# Iteration #9 - Objective function value:  0.14 - time: 9.399
# Iteration #10 - Objective function value:  0.14 - time: 8.313
# Iteration #11 - Objective function value:  0.13 - time: 9.278
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.09262292087078094
# repetition = 93
# Iteration #0 - Objective function value:  0.11 - time: 13.956
# Iteration #1 - Objective function value:  0.11 - time: 9.700
# Iteration #2 - Objective function value:  0.10 - time: 9.365
# Iteration #3 - Objective function value:  0.10 - time: 8.183
# Iteration #4 - Objective function value:  0.10 - time: 9.160
# Iteration #5 - Objective function value:  0.10 - time: 9.150
# Iteration #6 - Objective function value:  0.10 - time: 8.597
# Iteration #7 - Objective function value:  0.10 - time: 8.883
# Iteration #8 - Objective function value:  0.10 - time: 9.218
# Iteration #9 - Objective function value:  0.08 - time: 9.101
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.3947233557701111
# repetition = 94
# Iteration #0 - Objective function value:  0.26 - time: 13.749
# Iteration #1 - Objective function value:  0.26 - time: 9.108
# Iteration #2 - Objective function value:  0.26 - time: 9.305
# Iteration #3 - Objective function value:  0.26 - time: 9.590
# Iteration #4 - Objective function value:  0.26 - time: 9.832
# Iteration #5 - Objective function value:  0.25 - time: 8.601
# Iteration #6 - Objective function value:  0.25 - time: 9.527
# Iteration #7 - Objective function value:  0.25 - time: 9.481
# Iteration #8 - Objective function value:  0.25 - time: 9.532
# Iteration #9 - Objective function value:  0.25 - time: 8.607
# Iteration #10 - Objective function value:  0.23 - time: 9.574
# Iteration #11 - Objective function value:  0.22 - time: 9.276
# Iteration #12 - Objective function value:  0.20 - time: 9.326
# Iteration #13 - Objective function value:  0.20 - time: 8.446
# Iteration #14 - Objective function value:  0.20 - time: 9.231
# Iteration #15 - Objective function value:  0.20 - time: 9.250
# Iteration #16 - Objective function value:  0.20 - time: 8.108
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 1.376744031906128
# repetition = 95
# Iteration #0 - Objective function value:  0.06 - time: 14.746
# Iteration #1 - Objective function value:  0.06 - time: 8.751
# Iteration #2 - Objective function value:  0.06 - time: 9.428
# Iteration #3 - Objective function value:  0.06 - time: 9.395
# Iteration #4 - Objective function value:  0.04 - time: 8.068
# Iteration #5 - Objective function value:  0.04 - time: 9.300
# Iteration #6 - Objective function value:  0.04 - time: 9.454
# Iteration #7 - Objective function value:  0.04 - time: 9.081
# Iteration #8 - Objective function value:  0.03 - time: 8.597
# Iteration #9 - Objective function value:  0.03 - time: 9.113
# Iteration #10 - Objective function value:  0.03 - time: 9.639
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.5795009732246399
# repetition = 96
# Iteration #0 - Objective function value:  0.07 - time: 14.551
# Iteration #1 - Objective function value:  0.07 - time: 9.641
# Iteration #2 - Objective function value:  0.07 - time: 8.558
# Iteration #3 - Objective function value:  0.07 - time: 9.560
# Iteration #4 - Objective function value:  0.07 - time: 9.668
# Iteration #5 - Objective function value:  0.07 - time: 9.628
# Iteration #6 - Objective function value:  0.07 - time: 8.558
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.3049229383468628
# repetition = 97
# Iteration #0 - Objective function value:  0.15 - time: 14.423
# Iteration #1 - Objective function value:  0.15 - time: 9.097
# Iteration #2 - Objective function value:  0.15 - time: 9.410
# Iteration #3 - Objective function value:  0.15 - time: 9.470
# Iteration #4 - Objective function value:  0.15 - time: 8.292
# Iteration #5 - Objective function value:  0.15 - time: 9.186
# Iteration #6 - Objective function value:  0.15 - time: 9.221
# Iteration #7 - Objective function value:  0.14 - time: 8.633
# Iteration #8 - Objective function value:  0.14 - time: 8.934
# Iteration #9 - Objective function value:  0.14 - time: 9.288
# Iteration #10 - Objective function value:  0.14 - time: 9.232
# Iteration #11 - Objective function value:  0.14 - time: 8.122
# Iteration #12 - Objective function value:  0.11 - time: 9.379
# Iteration #13 - Objective function value:  0.11 - time: 9.253
# Iteration #14 - Objective function value:  0.11 - time: 7.937
# Iteration #15 - Objective function value:  0.11 - time: 9.239
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.2443462759256363
# repetition = 98
# Iteration #0 - Objective function value:  0.40 - time: 13.809
# Iteration #1 - Objective function value:  0.37 - time: 9.516
# Iteration #2 - Objective function value:  0.37 - time: 9.776
# Iteration #3 - Objective function value:  0.37 - time: 9.244
# Iteration #4 - Objective function value:  0.37 - time: 9.205
# Iteration #5 - Objective function value:  0.37 - time: 9.642
# Iteration #6 - Objective function value:  0.37 - time: 9.672
# Iteration #7 - Objective function value:  0.36 - time: 8.686
# Iteration #8 - Objective function value:  0.36 - time: 9.473
# Iteration #9 - Objective function value:  0.36 - time: 9.339
# Iteration #10 - Objective function value:  0.19 - time: 9.546
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.01972946524620056
# repetition = 99
# [[50, 9, 1.5, 83.70230645499998, 0.22222985], [50, 11, 1.5, 98.84656101599995, 0.45024714], [50, 14, 1.5, 130.68756172300004, 0.013290803], [50, 7, 1.5, 66.27731655100001, 0.49879366], [50, 12, 1.5, 110.10844250000002, 0.22728094], [50, 8, 1.5, 75.2413735670001, 1.1567006], [50, 17, 1.5, 155.60412642799986, 0.7968387], [50, 7, 1.5, 66.52253286100017, 0.43404984], [50, 8, 1.5, 73.79666009199991, 0.10887186], [50, 8, 1.5, 75.51515752699993, 0.71683115], [50, 12, 1.5, 110.37412416699999, 0.5047113], [50, 16, 1.5, 145.94070763900004, 0.07442531], [50, 10, 1.5, 92.67558694500008, 0.73811716], [50, 12, 1.5, 110.49448359500002, 0.34575146], [50, 13, 1.5, 120.729306898, 0.3450072], [50, 16, 1.5, 147.68122338800003, 0.589971], [50, 16, 1.5, 146.70885804, 0.06472493], [50, 7, 1.5, 66.9670557520003, 0.24180475], [50, 17, 1.5, 154.86687243000006, 0.17905858], [50, 15, 1.5, 139.3071942030001, 0.06418774], [50, 13, 1.5, 119.71719294700006, 1.1470274], [50, 10, 1.5, 93.81776806699963, 1.0805867], [50, 13, 1.5, 121.57542720699985, 0.0023222861], [50, 13, 1.5, 122.53871938400016, 0.41976106], [50, 14, 1.5, 130.17938132300014, 0.31584984], [50, 12, 1.5, 113.52992152099978, 1.1122402], [50, 12, 1.5, 111.38905340500014, 0.07628672], [50, 10, 1.5, 94.2530589500002, 0.1355208], [50, 9, 1.5, 87.09899073800034, 0.03892957], [50, 12, 1.5, 112.15993664500002, 0.6788383], [50, 13, 1.5, 124.66458774699959, 0.16230181], [50, 12, 1.5, 111.67942955299986, 0.28916764], [50, 8, 1.5, 78.20532373500009, 0.5832535], [50, 12, 1.5, 112.52956888900007, 0.3584645], [50, 10, 1.5, 95.43203344499943, 0.4915106], [50, 14, 1.5, 132.09916970699942, 0.076955475], [50, 11, 1.5, 105.09212479300004, 0.04953681], [50, 15, 1.5, 141.63200508800037, 0.1329597], [50, 10, 1.5, 95.62945124899943, 0.8442437], [50, 15, 1.5, 140.20388047699998, 0.2826091], [50, 12, 1.5, 113.5459213819995, 0.21866351], [50, 17, 1.5, 156.4552230240006, 0.17206542], [50, 15, 1.5, 141.58795841400024, 0.22122087], [50, 8, 1.5, 77.34778044299946, 0.70096684], [50, 9, 1.5, 87.10675230299967, 0.18050818], [50, 7, 1.5, 69.41466056399986, 0.113754734], [50, 14, 1.5, 132.99399629599975, 0.53130734], [50, 10, 1.5, 97.04117565900015, 1.4060129], [50, 9, 1.5, 85.57095156000014, 0.673577], [50, 11, 1.5, 105.0143344879998, 0.14645715], [50, 15, 1.5, 141.86447317799957, 0.40694663], [50, 9, 1.5, 86.6593049990006, 0.19814032], [50, 9, 1.5, 90.9705319879995, 0.53792405], [50, 17, 1.5, 161.84642754499964, 0.13540587], [50, 10, 1.5, 101.42889651600035, 0.11127887], [50, 9, 1.5, 88.6559533969994, 0.24682593], [50, 8, 1.5, 78.91567056200074, 0.14745006], [50, 17, 1.5, 159.30939021999984, 0.67399865], [50, 11, 1.5, 105.36531046699929, 0.32183522], [50, 16, 1.5, 149.492990707, 0.009733427], [50, 9, 1.5, 88.15972214999965, 0.054163665], [50, 14, 1.5, 131.10750188699967, 0.5782725], [50, 9, 1.5, 86.92549671400047, 0.40660408], [50, 11, 1.5, 104.89045593999981, 0.5802763], [50, 11, 1.5, 102.38818602799984, 0.3304627], [50, 7, 1.5, 70.24638816800052, 0.45719844], [50, 9, 1.5, 87.096985356, 0.3520803], [50, 11, 1.5, 103.66057486299997, 0.044491433], [50, 8, 1.5, 78.29038413600028, 0.17095913], [50, 6, 1.5, 60.3353115459995, 0.47087443], [50, 17, 1.5, 161.96838655900046, 0.22349362], [50, 17, 1.5, 156.570555796, 0.002505452], [50, 6, 1.5, 61.947257331999936, 0.41420975], [50, 16, 1.5, 151.17424592899988, 0.9734781], [50, 10, 1.5, 99.81214090700087, 0.7200767], [50, 14, 1.5, 134.87160771900017, 0.11889385], [50, 6, 1.5, 60.004538623999906, 0.27316314], [50, 13, 1.5, 128.44972016099928, 0.13235104], [50, 11, 1.5, 103.89417939499981, 0.35419416], [50, 6, 1.5, 61.41998650499954, 0.2801943], [50, 6, 1.5, 59.73434024599919, 0.3326551], [50, 12, 1.5, 112.58405759499874, 0.46132916], [50, 13, 1.5, 126.51062832400021, 0.16842435], [50, 14, 1.5, 131.47951884100075, 0.18130766], [50, 13, 1.5, 126.38863964400116, 0.3157515], [50, 12, 1.5, 113.14715325500038, 0.10881691], [50, 16, 1.5, 151.490433261999, 0.73374], [50, 8, 1.5, 76.44362074799938,  ...

# %%
df_ga = pd.DataFrame(data = ga_variables)

print(df_ga)
from google.colab import drive
drive.mount('/content/drive')

with open('/content/drive/MyDrive/TESI/Colab Notebooks/IT 6-18, POP=50, X_MAX=1.5/GA_SPHFUN ITERATION 6-18.txt', 'a') as file:
        df_ga.to_csv(file, sep = '\t', index=False, mode= 'a', header = ['x','x','x','x','x'])
# Out:
#      0   1    2           3         4
# 0   50   9  1.5   83.702306  0.222230
# 1   50  11  1.5   98.846561  0.450247
# 2   50  14  1.5  130.687562  0.013291
# 3   50   7  1.5   66.277317  0.498794
# 4   50  12  1.5  110.108443  0.227281
# ..  ..  ..  ...         ...       ...
# 95  50  17  1.5  160.550655  1.376744
# 96  50  11  1.5  105.576687  0.579501
# 97  50   7  1.5   70.166577  0.304923
# 98  50  16  1.5  149.121066  0.244346
# 99  50  11  1.5  107.911576  0.019729
#
# [100 rows x 5 columns]
# Mounted at /content/drive

# %%
#@title Class WOA

class WOA(Meta):

    def __init__(self, net_structure):
        super().__init__(net_structure)
        self.b  = 1 # spiral_shape_param

    def set_options(self, spiral_shape_param = 1):
        self.b = spiral_shape_param

    def set_max_x(self, max_x):
        self.max_x = max_x
    # I update the position using the equations determined from the case corresponding to the values of p andA
    def update_position(self, A, global_best_position, whales, C, l, p, i ):
        if p < 0.5:
            if abs(A) < 1:
                D = abs(C * global_best_position - whales[i])
                new_position = global_best_position - A * D
            else:
                X_rand = np.random.uniform(-self.max_x, self.max_x)
                D = abs(C * X_rand - whales[i])
                new_position = C * X_rand - whales[i]
        else:
            D = abs(global_best_position - whales[i])
            new_position = global_best_position + D * math.exp(self.b * l) * math.cos(2 * math.pi * l)
        return new_position


    def optimize(self):
        whales = np.random.uniform(low=-self.max_x, high=self.max_x, size=(self.population_size, self.num_parameters))
        best_positions = np.copy(whales)
        best_scores = np.array([self.num_parameters] * self.population_size)
        global_best_position = np.copy(whales[0])
        global_best_score = 1e10
        nl = len(self.model.layers)

        for iteration in range(self.num_iterations):
            tic_global = time.perf_counter()
            counter = 0

            for i in range(self.population_size):
                whale = whales[i,]
                wbindex = 0
                # WOA paramters
                r = np.random.randn()
                a = 2 - iteration * (2 / self.num_iterations)
                A = 2 * a * r - a
                C = 2 * r
                p = np.random.rand()
                l = np.random.uniform(-1,1)


                for p in range(0, nl):
                    W = whale[wbindex:(wbindex + self.model.layers[p].input.shape[1] * self.model.layers[p].output.shape[1])]
                    b = whale[(wbindex + self.model.layers[p].input.shape[1] * self.model.layers[p].output.shape[1]):(wbindex + self.model.layers[p].count_params())]
                    self.model.layers[p].set_weights([W.reshape(self.model.layers[p].input.shape[1], self.model.layers[p].output.shape[1]), b])
                    wbindex = (wbindex + self.model.layers[p].count_params())

                fitness = self.objective_function(n_samples = 1000)

                if  fitness < best_scores[i]:
                    best_scores[i] = fitness
                    best_positions[i] = np.copy(whales[i])


                if  fitness < global_best_score:
                    global_best_score = fitness
                    global_best_position = np.copy(whales[i])

                whales[i] = self.update_position(A, global_best_position, whales, C, l, p, i)

            # check that the adjourned positions are not outside the domain
            whales  = np.minimum(whales,  self.max_x)
            whales  = np.maximum(whales, -self.max_x)

            toc_global = time.perf_counter()
            print("Iteration #%d - Objective function value: %5.2f - time: %0.3f " % (iteration, global_best_score, toc_global - tic_global))

            if (global_best_score == 0):
                break

        return global_best_position

    def predict(self, x = None):
        return self.model.predict(x)

# %%
#@title Code for traing and test with WOA

net = NetStructure(input_dim=2, output_dim=1)
net.add_hidden(hidden_dim=5)


met = WOA(net)
met.set_population_size(50)
met.set_max_x(1.5)

sample_size = 1000
domain = [-1, 1]

repetitions = 100
woa_variables = []

# TRAIN
for i in range(repetitions):
    x = np.random.randint(6, 18)
    met.set_num_iterations(x)
    time_start = time.perf_counter()
    optimized_params = met.optimize()
    time_end = time.perf_counter()
    time_woa = time_end - time_start
    met.update_model_with_parameters(optimized_params)

    X_test = np.random.uniform(low=1, high=2, size=(sample_size, 2))

    # TEST
    y_pred_test = met.predict(X_test)
    mse_test = np.mean((y_pred_test.flatten() - y_pred_test)**2)
    print(f"Mean Squared Error on Test Set: {mse_test}")

    variables = [[met.population_size, x, met.max_x, time_woa, mse_test]]
    woa_variables = woa_variables + variables

    print("repetition =",i)


print(woa_variables)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Iteration #0 - Objective function value:  0.09 - time: 9.539
# Iteration #1 - Objective function value:  0.04 - time: 7.197
# Iteration #2 - Objective function value:  0.03 - time: 7.062
# Iteration #3 - Objective function value:  0.01 - time: 8.207
# Iteration #4 - Objective function value:  0.01 - time: 6.363
# Iteration #5 - Objective function value:  0.01 - time: 7.880
# Iteration #6 - Objective function value:  0.01 - time: 6.593
# Iteration #7 - Objective function value:  0.01 - time: 7.983
# Iteration #8 - Objective function value:  0.01 - time: 6.454
# Iteration #9 - Objective function value:  0.01 - time: 7.966
# Iteration #10 - Objective function value:  0.01 - time: 6.470
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.30234652757644653
# repetition = 0
# Iteration #0 - Objective function value:  0.06 - time: 8.036
# Iteration #1 - Objective function value:  0.03 - time: 6.479
# Iteration #2 - Objective function value:  0.02 - time: 7.800
# Iteration #3 - Objective function value:  0.01 - time: 6.651
# Iteration #4 - Objective function value:  0.01 - time: 7.729
# Iteration #5 - Objective function value:  0.01 - time: 6.773
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Mean Squared Error on Test Set: 0.28448382019996643
# repetition = 1
# Iteration #0 - Objective function value:  0.24 - time: 7.333
# Iteration #1 - Objective function value:  0.15 - time: 6.846
# Iteration #2 - Objective function value:  0.14 - time: 7.081
# Iteration #3 - Objective function value:  0.13 - time: 7.293
# Iteration #4 - Objective function value:  0.13 - time: 7.474
# Iteration #5 - Objective function value:  0.13 - time: 8.212
# Iteration #6 - Objective function value:  0.12 - time: 6.782
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.07203646749258041
# repetition = 2
# Iteration #0 - Objective function value:  0.12 - time: 8.472
# Iteration #1 - Objective function value:  0.03 - time: 6.939
# Iteration #2 - Objective function value:  0.03 - time: 8.351
# Iteration #3 - Objective function value:  0.03 - time: 7.318
# Iteration #4 - Objective function value:  0.02 - time: 8.005
# Iteration #5 - Objective function value:  0.02 - time: 8.263
# Iteration #6 - Objective function value:  0.02 - time: 6.752
# Iteration #7 - Objective function value:  0.02 - time: 8.286
# Iteration #8 - Objective function value:  0.02 - time: 6.546
# Iteration #9 - Objective function value:  0.02 - time: 8.203
# Iteration #10 - Objective function value:  0.01 - time: 6.536
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.3779394328594208
# repetition = 3
# Iteration #0 - Objective function value:  0.06 - time: 7.786
# Iteration #1 - Objective function value:  0.04 - time: 6.678
# Iteration #2 - Objective function value:  0.04 - time: 7.821
# Iteration #3 - Objective function value:  0.04 - time: 6.842
# Iteration #4 - Objective function value:  0.04 - time: 7.468
# Iteration #5 - Objective function value:  0.04 - time: 6.937
# Iteration #6 - Objective function value:  0.04 - time: 7.441
# Iteration #7 - Objective function value:  0.04 - time: 7.841
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Mean Squared Error on Test Set: 0.5936552882194519
# repetition = 4
# Iteration #0 - Objective function value:  0.42 - time: 6.637
# Iteration #1 - Objective function value:  0.16 - time: 7.890
# Iteration #2 - Objective function value:  0.08 - time: 6.491
# Iteration #3 - Objective function value:  0.08 - time: 7.932
# Iteration #4 - Objective function value:  0.07 - time: 6.457
# Iteration #5 - Objective function value:  0.07 - time: 7.771
# Iteration #6 - Objective function value:  0.07 - time: 6.319
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.8645850419998169
# repetition = 5
# Iteration #0 - Objective function value:  0.05 - time: 7.731
# Iteration #1 - Objective function value:  0.05 - time: 6.457
# Iteration #2 - Objective function value:  0.03 - time: 7.745
# Iteration #3 - Objective function value:  0.01 - time: 6.361
# Iteration #4 - Objective function value:  0.01 - time: 7.786
# Iteration #5 - Objective function value:  0.01 - time: 7.226
# Iteration #6 - Objective function value:  0.01 - time: 7.897
# Iteration #7 - Objective function value:  0.01 - time: 8.177
# Iteration #8 - Objective function value:  0.01 - time: 7.316
# Iteration #9 - Objective function value:  0.01 - time: 8.362
# Iteration #10 - Objective function value:  0.01 - time: 6.750
# Iteration #11 - Objective function value:  0.01 - time: 8.215
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.30863848328590393
# repetition = 6
# Iteration #0 - Objective function value:  0.24 - time: 6.602
# Iteration #1 - Objective function value:  0.09 - time: 8.036
# Iteration #2 - Objective function value:  0.09 - time: 7.008
# Iteration #3 - Objective function value:  0.07 - time: 7.580
# Iteration #4 - Objective function value:  0.07 - time: 6.985
# Iteration #5 - Objective function value:  0.06 - time: 7.192
# Iteration #6 - Objective function value:  0.06 - time: 7.656
# Iteration #7 - Objective function value:  0.06 - time: 7.097
# Iteration #8 - Objective function value:  0.06 - time: 7.926
# Iteration #9 - Objective function value:  0.06 - time: 6.452
# Iteration #10 - Objective function value:  0.06 - time: 7.746
# Iteration #11 - Objective function value:  0.05 - time: 6.461
# Iteration #12 - Objective function value:  0.05 - time: 7.893
# Iteration #13 - Objective function value:  0.05 - time: 6.520
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.09808127582073212
# repetition = 7
# Iteration #0 - Objective function value:  0.11 - time: 7.813
# Iteration #1 - Objective function value:  0.03 - time: 6.756
# Iteration #2 - Objective function value:  0.03 - time: 8.090
# Iteration #3 - Objective function value:  0.02 - time: 6.528
# Iteration #4 - Objective function value:  0.02 - time: 8.026
# Iteration #5 - Objective function value:  0.02 - time: 7.084
# Iteration #6 - Objective function value:  0.02 - time: 7.497
# Iteration #7 - Objective function value:  0.02 - time: 7.310
# Iteration #8 - Objective function value:  0.02 - time: 6.741
# Iteration #9 - Objective function value:  0.01 - time: 7.812
# Iteration #10 - Objective function value:  0.01 - time: 6.460
# Iteration #11 - Objective function value:  0.01 - time: 7.805
# Iteration #12 - Objective function value:  0.01 - time: 6.276
# Iteration #13 - Objective function value:  0.01 - time: 8.474
# Iteration #14 - Objective function value:  0.01 - time: 6.741
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.266101598739624
# repetition = 8
# Iteration #0 - Objective function value:  0.31 - time: 8.254
# Iteration #1 - Objective function value:  0.02 - time: 6.937
# Iteration #2 - Objective function value:  0.02 - time: 8.347
# Iteration #3 - Objective function value:  0.01 - time: 7.295
# Iteration #4 - Objective function value:  0.01 - time: 7.516
# Iteration #5 - Objective function value:  0.01 - time: 7.996
# Iteration #6 - Objective function value:  0.01 - time: 6.628
# Iteration #7 - Objective function value:  0.01 - time: 7.882
# Iteration #8 - Objective function value:  0.01 - time: 6.580
# Iteration #9 - Objective function value:  0.01 - time: 7.960
# Iteration #10 - Objective function value:  0.01 - time: 6.676
# Iteration #11 - Objective function value:  0.01 - time: 8.023
# Iteration #12 - Objective function value:  0.01 - time: 6.565
# Iteration #13 - Objective function value:  0.01 - time: 7.859
# Iteration #14 - Objective function value:  0.01 - time: 6.776
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Mean Squared Error on Test Set: 0.28442782163619995
# repetition = 9
# Iteration #0 - Objective function value:  0.07 - time: 7.446
# Iteration #1 - Objective function value:  0.01 - time: 7.201
# Iteration #2 - Objective function value:  0.01 - time: 7.078
# Iteration #3 - Objective function value:  0.01 - time: 8.108
# Iteration #4 - Objective function value:  0.01 - time: 6.584
# Iteration #5 - Objective function value:  0.01 - time: 8.020
# Iteration #6 - Objective function value:  0.01 - time: 6.465
# Iteration #7 - Objective function value:  0.01 - time: 7.951
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.30434703826904297
# repetition = 10
# Iteration #0 - Objective function value:  0.17 - time: 6.413
# Iteration #1 - Objective function value:  0.11 - time: 7.925
# Iteration #2 - Objective function value:  0.06 - time: 6.304
# Iteration #3 - Objective function value:  0.03 - time: 7.808
# Iteration #4 - Objective function value:  0.03 - time: 6.396
# Iteration #5 - Objective function value:  0.02 - time: 8.019
# Iteration #6 - Objective function value:  0.02 - time: 6.608
# Iteration #7 - Objective function value:  0.02 - time: 7.476
# Iteration #8 - Objective function value:  0.02 - time: 6.979
# Iteration #9 - Objective function value:  0.02 - time: 7.923
# Iteration #10 - Objective function value:  0.02 - time: 8.221
# Iteration #11 - Objective function value:  0.02 - time: 6.816
# Iteration #12 - Objective function value:  0.02 - time: 8.155
# Iteration #13 - Objective function value:  0.02 - time: 6.682
# Iteration #14 - Objective function value:  0.02 - time: 8.252
# Iteration #15 - Objective function value:  0.02 - time: 6.700
# Iteration #16 - Objective function value:  0.02 - time: 8.123
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.25623491406440735
# repetition = 11
# Iteration #0 - Objective function value:  0.05 - time: 7.024
# Iteration #1 - Objective function value:  0.05 - time: 7.557
# Iteration #2 - Objective function value:  0.05 - time: 7.703
# Iteration #3 - Objective function value:  0.04 - time: 7.015
# Iteration #4 - Objective function value:  0.04 - time: 7.731
# Iteration #5 - Objective function value:  0.04 - time: 6.553
# Iteration #6 - Objective function value:  0.04 - time: 7.858
# Iteration #7 - Objective function value:  0.04 - time: 6.373
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.13038860261440277
# repetition = 12
# Iteration #0 - Objective function value:  0.12 - time: 7.953
# Iteration #1 - Objective function value:  0.12 - time: 6.440
# Iteration #2 - Objective function value:  0.09 - time: 7.872
# Iteration #3 - Objective function value:  0.05 - time: 6.539
# Iteration #4 - Objective function value:  0.04 - time: 7.838
# Iteration #5 - Objective function value:  0.04 - time: 6.483
# Iteration #6 - Objective function value:  0.04 - time: 7.706
# Iteration #7 - Objective function value:  0.04 - time: 6.875
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Mean Squared Error on Test Set: 0.15079756081104279
# repetition = 13
# Iteration #0 - Objective function value:  0.31 - time: 7.406
# Iteration #1 - Objective function value:  0.18 - time: 7.236
# Iteration #2 - Objective function value:  0.07 - time: 7.023
# Iteration #3 - Objective function value:  0.05 - time: 8.117
# Iteration #4 - Objective function value:  0.05 - time: 6.433
# Iteration #5 - Objective function value:  0.05 - time: 7.799
# Iteration #6 - Objective function value:  0.05 - time: 6.295
# Iteration #7 - Objective function value:  0.05 - time: 7.699
# Iteration #8 - Objective function value:  0.05 - time: 6.482
# Iteration #9 - Objective function value:  0.05 - time: 7.868
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.2639646530151367
# repetition = 14
# Iteration #0 - Objective function value:  0.02 - time: 6.786
# Iteration #1 - Objective function value:  0.02 - time: 8.336
# Iteration #2 - Objective function value:  0.02 - time: 7.068
# Iteration #3 - Objective function value:  0.02 - time: 8.282
# Iteration #4 - Objective function value:  0.01 - time: 8.318
# Iteration #5 - Objective function value:  0.01 - time: 6.811
# Iteration #6 - Objective function value:  0.01 - time: 8.141
# Iteration #7 - Objective function value:  0.01 - time: 6.712
# Iteration #8 - Objective function value:  0.01 - time: 8.373
# Iteration #9 - Objective function value:  0.01 - time: 6.637
# Iteration #10 - Objective function value:  0.01 - time: 8.177
# Iteration #11 - Objective function value:  0.01 - time: 7.096
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Mean Squared Error on Test Set: 0.3784812092781067
# repetition = 15
# Iteration #0 - Objective function value:  0.05 - time: 7.571
# Iteration #1 - Objective function value:  0.04 - time: 7.767
# Iteration #2 - Objective function value:  0.03 - time: 6.836
# Iteration #3 - Objective function value:  0.03 - time: 8.016
# Iteration #4 - Objective function value:  0.02 - time: 6.545
# Iteration #5 - Objective function value:  0.02 - time: 7.936
# Iteration #6 - Objective function value:  0.02 - time: 6.647
# Iteration #7 - Objective function value:  0.02 - time: 7.691
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.22683967649936676
# repetition = 16
# Iteration #0 - Objective function value:  0.19 - time: 6.476
# Iteration #1 - Objective function value:  0.18 - time: 7.775
# Iteration #2 - Objective function value:  0.15 - time: 6.475
# Iteration #3 - Objective function value:  0.11 - time: 7.900
# Iteration #4 - Objective function value:  0.11 - time: 6.625
# Iteration #5 - Objective function value:  0.11 - time: 7.566
# Iteration #6 - Objective function value:  0.11 - time: 7.020
# Iteration #7 - Objective function value:  0.10 - time: 7.312
# Iteration #8 - Objective function value:  0.10 - time: 7.575
# Iteration #9 - Objective function value:  0.10 - time: 6.597
# Iteration #10 - Objective function value:  0.10 - time: 7.676
# Iteration #11 - Objective function value:  0.10 - time: 6.230
# Iteration #12 - Objective function value:  0.10 - time: 7.661
# Iteration #13 - Objective function value:  0.10 - time: 6.455
# Iteration #14 - Objective function value:  0.10 - time: 8.334
# Iteration #15 - Objective function value:  0.10 - time: 6.900
# Iteration #16 - Objective function value:  0.10 - time: 8.440
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.3732324540615082
# repetition = 17
# Iteration #0 - Objective function value:  0.10 - time: 7.000
# Iteration #1 - Objective function value:  0.10 - time: 8.189
# Iteration #2 - Objective function value:  0.02 - time: 7.602
# Iteration #3 - Objective function value:  0.02 - time: 7.241
# Iteration #4 - Objective function value:  0.02 - time: 8.124
# Iteration #5 - Objective function value:  0.01 - time: 6.584
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.4203013777732849
# repetition = 18
# Iteration #0 - Objective function value:  0.05 - time: 8.241
# Iteration #1 - Objective function value:  0.04 - time: 6.583
# Iteration #2 - Objective function value:  0.02 - time: 8.139
# Iteration #3 - Objective function value:  0.01 - time: 6.693
# Iteration #4 - Objective function value:  0.01 - time: 8.034
# Iteration #5 - Objective function value:  0.01 - time: 7.209
# Iteration #6 - Objective function value:  0.01 - time: 7.530
# Iteration #7 - Objective function value:  0.01 - time: 8.293
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.30094093084335327
# repetition = 19
# Iteration #0 - Objective function value:  0.24 - time: 6.744
# Iteration #1 - Objective function value:  0.07 - time: 8.182
# Iteration #2 - Objective function value:  0.06 - time: 6.483
# Iteration #3 - Objective function value:  0.06 - time: 7.960
# Iteration #4 - Objective function value:  0.06 - time: 6.480
# Iteration #5 - Objective function value:  0.06 - time: 7.932
# Iteration #6 - Objective function value:  0.06 - time: 6.470
# Iteration #7 - Objective function value:  0.06 - time: 7.536
# Iteration #8 - Objective function value:  0.06 - time: 6.444
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.444562166929245
# repetition = 20
# Iteration #0 - Objective function value:  0.25 - time: 7.737
# Iteration #1 - Objective function value:  0.11 - time: 6.437
# Iteration #2 - Objective function value:  0.05 - time: 7.594
# Iteration #3 - Objective function value:  0.03 - time: 6.963
# Iteration #4 - Objective function value:  0.03 - time: 7.292
# Iteration #5 - Objective function value:  0.03 - time: 7.320
# Iteration #6 - Objective function value:  0.03 - time: 6.838
# Iteration #7 - Objective function value:  0.03 - time: 7.445
# Iteration #8 - Objective function value:  0.03 - time: 7.021
# Iteration #9 - Objective function value:  0.03 - time: 8.244
# Iteration #10 - Objective function value:  0.03 - time: 6.896
# Iteration #11 - Objective function value:  0.03 - time: 8.167
# Iteration #12 - Objective function value:  0.03 - time: 6.699
# Iteration #13 - Objective function value:  0.03 - time: 8.022
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.28373968601226807
# repetition = 21
# Iteration #0 - Objective function value:  0.10 - time: 6.535
# Iteration #1 - Objective function value:  0.07 - time: 8.133
# Iteration #2 - Objective function value:  0.07 - time: 7.104
# Iteration #3 - Objective function value:  0.06 - time: 7.443
# Iteration #4 - Objective function value:  0.06 - time: 7.796
# Iteration #5 - Objective function value:  0.06 - time: 6.821
# Iteration #6 - Objective function value:  0.06 - time: 7.948
# Iteration #7 - Objective function value:  0.06 - time: 6.626
# Iteration #8 - Objective function value:  0.06 - time: 8.078
# Iteration #9 - Objective function value:  0.06 - time: 6.670
# Iteration #10 - Objective function value:  0.06 - time: 8.080
# Iteration #11 - Objective function value:  0.06 - time: 6.585
# Iteration #12 - Objective function value:  0.06 - time: 8.173
# Iteration #13 - Objective function value:  0.06 - time: 6.595
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.7521650791168213
# repetition = 22
# Iteration #0 - Objective function value:  0.22 - time: 7.610
# Iteration #1 - Objective function value:  0.03 - time: 6.729
# Iteration #2 - Objective function value:  0.03 - time: 7.529
# Iteration #3 - Objective function value:  0.03 - time: 7.002
# Iteration #4 - Objective function value:  0.02 - time: 7.164
# Iteration #5 - Objective function value:  0.02 - time: 7.501
# Iteration #6 - Objective function value:  0.02 - time: 6.680
# Iteration #7 - Objective function value:  0.02 - time: 7.902
# Iteration #8 - Objective function value:  0.02 - time: 6.452
# Iteration #9 - Objective function value:  0.02 - time: 7.950
# Iteration #10 - Objective function value:  0.02 - time: 6.387
# Iteration #11 - Objective function value:  0.02 - time: 7.870
# Iteration #12 - Objective function value:  0.02 - time: 6.323
# Iteration #13 - Objective function value:  0.02 - time: 7.811
# Iteration #14 - Objective function value:  0.02 - time: 6.854
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.2639440894126892
# repetition = 23
# Iteration #0 - Objective function value:  0.03 - time: 8.345
# Iteration #1 - Objective function value:  0.03 - time: 7.166
# Iteration #2 - Objective function value:  0.02 - time: 7.821
# Iteration #3 - Objective function value:  0.02 - time: 8.006
# Iteration #4 - Objective function value:  0.01 - time: 6.841
# Iteration #5 - Objective function value:  0.01 - time: 8.107
# Iteration #6 - Objective function value:  0.01 - time: 6.566
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.32042446732521057
# repetition = 24
# Iteration #0 - Objective function value:  0.24 - time: 7.938
# Iteration #1 - Objective function value:  0.16 - time: 6.579
# Iteration #2 - Objective function value:  0.11 - time: 8.175
# Iteration #3 - Objective function value:  0.11 - time: 6.677
# Iteration #4 - Objective function value:  0.11 - time: 8.120
# Iteration #5 - Objective function value:  0.11 - time: 7.160
# Iteration #6 - Objective function value:  0.11 - time: 7.804
# Iteration #7 - Objective function value:  0.11 - time: 8.123
# Iteration #8 - Objective function value:  0.11 - time: 6.716
# Iteration #9 - Objective function value:  0.11 - time: 7.900
# Iteration #10 - Objective function value:  0.11 - time: 6.618
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.15670888125896454
# repetition = 25
# Iteration #0 - Objective function value:  0.05 - time: 7.865
# Iteration #1 - Objective function value:  0.05 - time: 6.490
# Iteration #2 - Objective function value:  0.04 - time: 7.943
# Iteration #3 - Objective function value:  0.03 - time: 6.522
# Iteration #4 - Objective function value:  0.03 - time: 7.910
# Iteration #5 - Objective function value:  0.03 - time: 6.595
# Iteration #6 - Objective function value:  0.03 - time: 7.776
# Iteration #7 - Objective function value:  0.03 - time: 6.668
# Iteration #8 - Objective function value:  0.03 - time: 7.445
# Iteration #9 - Objective function value:  0.03 - time: 7.068
# Iteration #10 - Objective function value:  0.03 - time: 7.259
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.49801090359687805
# repetition = 26
# Iteration #0 - Objective function value:  0.08 - time: 7.759
# Iteration #1 - Objective function value:  0.03 - time: 6.711
# Iteration #2 - Objective function value:  0.03 - time: 7.530
# Iteration #3 - Objective function value:  0.03 - time: 6.342
# Iteration #4 - Objective function value:  0.02 - time: 8.186
# Iteration #5 - Objective function value:  0.02 - time: 6.842
# Iteration #6 - Objective function value:  0.02 - time: 8.188
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.21419785916805267
# repetition = 27
# Iteration #0 - Objective function value:  0.10 - time: 6.811
# Iteration #1 - Objective function value:  0.08 - time: 8.040
# Iteration #2 - Objective function value:  0.05 - time: 6.865
# Iteration #3 - Objective function value:  0.03 - time: 7.733
# Iteration #4 - Objective function value:  0.02 - time: 7.189
# Iteration #5 - Objective function value:  0.02 - time: 7.542
# Iteration #6 - Objective function value:  0.02 - time: 7.670
# Iteration #7 - Objective function value:  0.01 - time: 6.624
# Iteration #8 - Objective function value:  0.01 - time: 8.047
# Iteration #9 - Objective function value:  0.01 - time: 6.583
# Iteration #10 - Objective function value:  0.01 - time: 7.944
# Iteration #11 - Objective function value:  0.01 - time: 6.548
# Iteration #12 - Objective function value:  0.01 - time: 7.776
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.3384650647640228
# repetition = 28
# Iteration #0 - Objective function value:  0.18 - time: 6.595
# Iteration #1 - Objective function value:  0.17 - time: 7.841
# Iteration #2 - Objective function value:  0.07 - time: 6.517
# Iteration #3 - Objective function value:  0.07 - time: 7.768
# Iteration #4 - Objective function value:  0.05 - time: 6.875
# Iteration #5 - Objective function value:  0.05 - time: 7.751
# Iteration #6 - Objective function value:  0.04 - time: 7.932
# Iteration #7 - Objective function value:  0.04 - time: 6.573
# Iteration #8 - Objective function value:  0.04 - time: 7.776
# Iteration #9 - Objective function value:  0.04 - time: 6.352
# Iteration #10 - Objective function value:  0.04 - time: 7.654
# Iteration #11 - Objective function value:  0.04 - time: 6.342
# Iteration #12 - Objective function value:  0.04 - time: 7.733
# Iteration #13 - Objective function value:  0.04 - time: 6.474
# Iteration #14 - Objective function value:  0.04 - time: 7.765
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Mean Squared Error on Test Set: 0.6193197965621948
# repetition = 29
# Iteration #0 - Objective function value:  0.10 - time: 6.489
# Iteration #1 - Objective function value:  0.01 - time: 7.714
# Iteration #2 - Objective function value:  0.01 - time: 6.386
# Iteration #3 - Objective function value:  0.01 - time: 8.297
# Iteration #4 - Objective function value:  0.01 - time: 6.673
# Iteration #5 - Objective function value:  0.01 - time: 8.168
# Iteration #6 - Objective function value:  0.01 - time: 7.961
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Mean Squared Error on Test Set: 0.3980327546596527
# repetition = 30
# Iteration #0 - Objective function value:  0.07 - time: 7.144
# Iteration #1 - Objective function value:  0.07 - time: 8.281
# Iteration #2 - Objective function value:  0.06 - time: 6.608
# Iteration #3 - Objective function value:  0.04 - time: 8.090
# Iteration #4 - Objective function value:  0.03 - time: 6.791
# Iteration #5 - Objective function value:  0.02 - time: 8.292
# Iteration #6 - Objective function value:  0.02 - time: 7.034
# Iteration #7 - Objective function value:  0.02 - time: 7.820
# Iteration #8 - Objective function value:  0.02 - time: 7.535
# Iteration #9 - Objective function value:  0.02 - time: 7.131
# Iteration #10 - Objective function value:  0.02 - time: 8.122
# Iteration #11 - Objective function value:  0.02 - time: 6.601
# Iteration #12 - Objective function value:  0.02 - time: 8.126
# Iteration #13 - Objective function value:  0.02 - time: 6.438
# Iteration #14 - Objective function value:  0.02 - time: 7.770
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.23022602498531342
# repetition = 31
# Iteration #0 - Objective function value:  0.27 - time: 6.502
# Iteration #1 - Objective function value:  0.26 - time: 7.586
# Iteration #2 - Objective function value:  0.16 - time: 6.494
# Iteration #3 - Objective function value:  0.08 - time: 7.740
# Iteration #4 - Objective function value:  0.07 - time: 6.502
# Iteration #5 - Objective function value:  0.02 - time: 7.882
# Iteration #6 - Objective function value:  0.01 - time: 6.783
# Iteration #7 - Objective function value:  0.01 - time: 7.441
# Iteration #8 - Objective function value:  0.01 - time: 7.369
# Iteration #9 - Objective function value:  0.01 - time: 7.236
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.3668420910835266
# repetition = 32
# Iteration #0 - Objective function value:  0.07 - time: 7.697
# Iteration #1 - Objective function value:  0.04 - time: 6.419
# Iteration #2 - Objective function value:  0.04 - time: 7.829
# Iteration #3 - Objective function value:  0.04 - time: 6.364
# Iteration #4 - Objective function value:  0.04 - time: 7.714
# Iteration #5 - Objective function value:  0.04 - time: 6.804
# Iteration #6 - Objective function value:  0.03 - time: 8.142
# Iteration #7 - Objective function value:  0.03 - time: 6.923
# Iteration #8 - Objective function value:  0.03 - time: 8.267
# Iteration #9 - Objective function value:  0.03 - time: 7.001
# Iteration #10 - Objective function value:  0.03 - time: 8.103
# Iteration #11 - Objective function value:  0.03 - time: 7.578
# Iteration #12 - Objective function value:  0.03 - time: 7.150
# Iteration #13 - Objective function value:  0.03 - time: 8.109
# Iteration #14 - Objective function value:  0.03 - time: 6.547
# Iteration #15 - Objective function value:  0.03 - time: 7.994
# Iteration #16 - Objective function value:  0.03 - time: 6.647
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.1732778698205948
# repetition = 33
# Iteration #0 - Objective function value:  0.06 - time: 8.014
# Iteration #1 - Objective function value:  0.03 - time: 6.548
# Iteration #2 - Objective function value:  0.03 - time: 7.986
# Iteration #3 - Objective function value:  0.01 - time: 6.578
# Iteration #4 - Objective function value:  0.01 - time: 7.964
# Iteration #5 - Objective function value:  0.01 - time: 6.903
# Iteration #6 - Objective function value:  0.01 - time: 7.273
# Iteration #7 - Objective function value:  0.01 - time: 7.190
# Iteration #8 - Objective function value:  0.01 - time: 7.263
# Iteration #9 - Objective function value:  0.01 - time: 7.804
# Iteration #10 - Objective function value:  0.01 - time: 6.514
# Iteration #11 - Objective function value:  0.01 - time: 7.834
# Iteration #12 - Objective function value:  0.01 - time: 6.458
# Iteration #13 - Objective function value:  0.01 - time: 7.959
# Iteration #14 - Objective function value:  0.01 - time: 6.394
# Iteration #15 - Objective function value:  0.01 - time: 7.868
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.30242669582366943
# repetition = 34
# Iteration #0 - Objective function value:  0.40 - time: 6.361
# Iteration #1 - Objective function value:  0.20 - time: 7.923
# Iteration #2 - Objective function value:  0.08 - time: 6.397
# Iteration #3 - Objective function value:  0.08 - time: 7.674
# Iteration #4 - Objective function value:  0.05 - time: 6.432
# Iteration #5 - Objective function value:  0.05 - time: 7.785
# Iteration #6 - Objective function value:  0.05 - time: 6.829
# Iteration #7 - Objective function value:  0.04 - time: 8.223
# Iteration #8 - Objective function value:  0.03 - time: 8.260
# Iteration #9 - Objective function value:  0.03 - time: 6.721
# Iteration #10 - Objective function value:  0.03 - time: 8.082
# Iteration #11 - Objective function value:  0.03 - time: 6.763
# Iteration #12 - Objective function value:  0.03 - time: 8.265
# Iteration #13 - Objective function value:  0.03 - time: 6.600
# Iteration #14 - Objective function value:  0.03 - time: 8.121
# Iteration #15 - Objective function value:  0.03 - time: 6.688
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Mean Squared Error on Test Set: 0.3548409938812256
# repetition = 35
# Iteration #0 - Objective function value:  0.11 - time: 7.956
# Iteration #1 - Objective function value:  0.11 - time: 7.682
# Iteration #2 - Objective function value:  0.10 - time: 7.039
# Iteration #3 - Objective function value:  0.05 - time: 8.110
# Iteration #4 - Objective function value:  0.01 - time: 6.571
# Iteration #5 - Objective function value:  0.01 - time: 8.008
# Iteration #6 - Objective function value:  0.01 - time: 6.378
# Iteration #7 - Objective function value:  0.01 - time: 7.979
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.3353837728500366
# repetition = 36
# Iteration #0 - Objective function value:  0.40 - time: 6.497
# Iteration #1 - Objective function value:  0.07 - time: 7.926
# Iteration #2 - Objective function value:  0.07 - time: 6.597
# Iteration #3 - Objective function value:  0.02 - time: 7.977
# Iteration #4 - Objective function value:  0.02 - time: 6.832
# Iteration #5 - Objective function value:  0.02 - time: 7.725
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.39663249254226685
# repetition = 37
# Iteration #0 - Objective function value:  0.30 - time: 7.076
# Iteration #1 - Objective function value:  0.11 - time: 7.288
# Iteration #2 - Objective function value:  0.07 - time: 7.843
# Iteration #3 - Objective function value:  0.05 - time: 6.640
# Iteration #4 - Objective function value:  0.05 - time: 7.943
# Iteration #5 - Objective function value:  0.04 - time: 6.307
# Iteration #6 - Objective function value:  0.04 - time: 7.861
# Iteration #7 - Objective function value:  0.03 - time: 6.545
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.28430822491645813
# repetition = 38
# Iteration #0 - Objective function value:  0.08 - time: 7.912
# Iteration #1 - Objective function value:  0.06 - time: 6.372
# Iteration #2 - Objective function value:  0.05 - time: 7.856
# Iteration #3 - Objective function value:  0.05 - time: 7.212
# Iteration #4 - Objective function value:  0.04 - time: 8.097
# Iteration #5 - Objective function value:  0.04 - time: 8.317
# Iteration #6 - Objective function value:  0.03 - time: 6.832
# Iteration #7 - Objective function value:  0.02 - time: 8.335
# Iteration #8 - Objective function value:  0.02 - time: 6.725
# Iteration #9 - Objective function value:  0.02 - time: 8.176
# Iteration #10 - Objective function value:  0.02 - time: 6.783
# Iteration #11 - Objective function value:  0.02 - time: 8.134
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.3799416124820709
# repetition = 39
# Iteration #0 - Objective function value:  0.03 - time: 7.230
# Iteration #1 - Objective function value:  0.03 - time: 7.655
# Iteration #2 - Objective function value:  0.02 - time: 7.663
# Iteration #3 - Objective function value:  0.02 - time: 6.857
# Iteration #4 - Objective function value:  0.02 - time: 8.066
# Iteration #5 - Objective function value:  0.02 - time: 6.591
# Iteration #6 - Objective function value:  0.02 - time: 7.876
# Iteration #7 - Objective function value:  0.02 - time: 6.634
# Iteration #8 - Objective function value:  0.01 - time: 7.923
# Iteration #9 - Objective function value:  0.01 - time: 6.642
# Iteration #10 - Objective function value:  0.01 - time: 7.933
# Iteration #11 - Objective function value:  0.01 - time: 6.536
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.35476288199424744
# repetition = 40
# Iteration #0 - Objective function value:  0.03 - time: 8.050
# Iteration #1 - Objective function value:  0.03 - time: 7.091
# Iteration #2 - Objective function value:  0.03 - time: 7.487
# Iteration #3 - Objective function value:  0.02 - time: 7.541
# Iteration #4 - Objective function value:  0.02 - time: 6.783
# Iteration #5 - Objective function value:  0.02 - time: 7.784
# Iteration #6 - Objective function value:  0.02 - time: 6.428
# Iteration #7 - Objective function value:  0.02 - time: 7.774
# Iteration #8 - Objective function value:  0.02 - time: 6.453
# Iteration #9 - Objective function value:  0.02 - time: 7.759
# Iteration #10 - Objective function value:  0.02 - time: 6.454
# Iteration #11 - Objective function value:  0.02 - time: 7.887
# Iteration #12 - Objective function value:  0.02 - time: 6.266
# Iteration #13 - Objective function value:  0.02 - time: 8.303
# Iteration #14 - Objective function value:  0.02 - time: 6.864
# Iteration #15 - Objective function value:  0.02 - time: 8.089
# Iteration #16 - Objective function value:  0.02 - time: 7.524
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Mean Squared Error on Test Set: 0.3065226674079895
# repetition = 41
# Iteration #0 - Objective function value:  0.21 - time: 7.417
# Iteration #1 - Objective function value:  0.09 - time: 8.420
# Iteration #2 - Objective function value:  0.02 - time: 6.846
# Iteration #3 - Objective function value:  0.01 - time: 8.517
# Iteration #4 - Objective function value:  0.01 - time: 7.070
# Iteration #5 - Objective function value:  0.01 - time: 8.128
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.33960703015327454
# repetition = 42
# Iteration #0 - Objective function value:  0.07 - time: 7.223
# Iteration #1 - Objective function value:  0.05 - time: 7.558
# Iteration #2 - Objective function value:  0.05 - time: 8.261
# Iteration #3 - Objective function value:  0.03 - time: 6.586
# Iteration #4 - Objective function value:  0.03 - time: 8.066
# Iteration #5 - Objective function value:  0.03 - time: 6.494
# Iteration #6 - Objective function value:  0.03 - time: 8.347
# Iteration #7 - Objective function value:  0.03 - time: 6.587
# Iteration #8 - Objective function value:  0.03 - time: 7.972
# Iteration #9 - Objective function value:  0.03 - time: 6.290
# Iteration #10 - Objective function value:  0.03 - time: 8.246
# Iteration #11 - Objective function value:  0.02 - time: 6.751
# Iteration #12 - Objective function value:  0.02 - time: 7.618
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.2451241910457611
# repetition = 43
# Iteration #0 - Objective function value:  0.13 - time: 7.954
# Iteration #1 - Objective function value:  0.07 - time: 6.404
# Iteration #2 - Objective function value:  0.07 - time: 7.973
# Iteration #3 - Objective function value:  0.05 - time: 6.541
# Iteration #4 - Objective function value:  0.05 - time: 7.960
# Iteration #5 - Objective function value:  0.04 - time: 6.405
# Iteration #6 - Objective function value:  0.03 - time: 7.730
# Iteration #7 - Objective function value:  0.03 - time: 6.422
# Iteration #8 - Objective function value:  0.03 - time: 7.972
# Iteration #9 - Objective function value:  0.03 - time: 6.405
# Iteration #10 - Objective function value:  0.02 - time: 7.884
# Iteration #11 - Objective function value:  0.02 - time: 6.879
# Iteration #12 - Objective function value:  0.02 - time: 8.177
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.2253001630306244
# repetition = 44
# Iteration #0 - Objective function value:  0.14 - time: 7.847
# Iteration #1 - Objective function value:  0.09 - time: 7.281
# Iteration #2 - Objective function value:  0.09 - time: 8.334
# Iteration #3 - Objective function value:  0.08 - time: 7.113
# Iteration #4 - Objective function value:  0.08 - time: 8.236
# Iteration #5 - Objective function value:  0.08 - time: 6.734
# Iteration #6 - Objective function value:  0.08 - time: 8.195
# Iteration #7 - Objective function value:  0.08 - time: 7.082
# Iteration #8 - Objective function value:  0.08 - time: 7.540
# Iteration #9 - Objective function value:  0.08 - time: 7.650
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Mean Squared Error on Test Set: 0.1762489378452301
# repetition = 45
# Iteration #0 - Objective function value:  0.11 - time: 6.871
# Iteration #1 - Objective function value:  0.11 - time: 8.089
# Iteration #2 - Objective function value:  0.07 - time: 6.509
# Iteration #3 - Objective function value:  0.06 - time: 7.925
# Iteration #4 - Objective function value:  0.04 - time: 6.609
# Iteration #5 - Objective function value:  0.03 - time: 8.162
# Iteration #6 - Objective function value:  0.03 - time: 6.682
# Iteration #7 - Objective function value:  0.02 - time: 8.022
# Iteration #8 - Objective function value:  0.02 - time: 6.722
# Iteration #9 - Objective function value:  0.02 - time: 7.759
# Iteration #10 - Objective function value:  0.02 - time: 7.132
# Iteration #11 - Objective function value:  0.01 - time: 7.325
# Iteration #12 - Objective function value:  0.01 - time: 7.269
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Mean Squared Error on Test Set: 0.2637188732624054
# repetition = 46
# Iteration #0 - Objective function value:  0.03 - time: 6.980
# Iteration #1 - Objective function value:  0.03 - time: 7.903
# Iteration #2 - Objective function value:  0.03 - time: 6.505
# Iteration #3 - Objective function value:  0.02 - time: 7.976
# Iteration #4 - Objective function value:  0.02 - time: 6.566
# Iteration #5 - Objective function value:  0.02 - time: 7.955
# Iteration #6 - Objective function value:  0.02 - time: 6.324
# Iteration #7 - Objective function value:  0.02 - time: 7.934
# Iteration #8 - Objective function value:  0.02 - time: 6.514
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.31938886642456055
# repetition = 47
# Iteration #0 - Objective function value:  0.07 - time: 8.205
# Iteration #1 - Objective function value:  0.02 - time: 7.281
# Iteration #2 - Objective function value:  0.02 - time: 7.993
# Iteration #3 - Objective function value:  0.01 - time: 8.155
# Iteration #4 - Objective function value:  0.01 - time: 6.942
# Iteration #5 - Objective function value:  0.01 - time: 8.179
# Iteration #6 - Objective function value:  0.01 - time: 6.623
# Iteration #7 - Objective function value:  0.01 - time: 8.235
# Iteration #8 - Objective function value:  0.01 - time: 6.641
# Iteration #9 - Objective function value:  0.01 - time: 8.020
# Iteration #10 - Objective function value:  0.01 - time: 6.810
# Iteration #11 - Objective function value:  0.01 - time: 7.910
# Iteration #12 - Objective function value:  0.01 - time: 7.301
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Mean Squared Error on Test Set: 0.37404030561447144
# repetition = 48
# Iteration #0 - Objective function value:  0.03 - time: 7.158
# Iteration #1 - Objective function value:  0.03 - time: 8.001
# Iteration #2 - Objective function value:  0.02 - time: 6.753
# Iteration #3 - Objective function value:  0.02 - time: 8.019
# Iteration #4 - Objective function value:  0.01 - time: 6.717
# Iteration #5 - Objective function value:  0.01 - time: 8.062
# Iteration #6 - Objective function value:  0.01 - time: 6.507
# Iteration #7 - Objective function value:  0.01 - time: 8.036
# Iteration #8 - Objective function value:  0.01 - time: 6.494
# Iteration #9 - Objective function value:  0.01 - time: 7.886
# Iteration #10 - Objective function value:  0.01 - time: 6.713
# Iteration #11 - Objective function value:  0.01 - time: 7.791
# Iteration #12 - Objective function value:  0.01 - time: 7.216
# Iteration #13 - Objective function value:  0.01 - time: 7.458
# Iteration #14 - Objective function value:  0.01 - time: 7.796
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Mean Squared Error on Test Set: 0.30922186374664307
# repetition = 49
# Iteration #0 - Objective function value:  0.07 - time: 6.521
# Iteration #1 - Objective function value:  0.03 - time: 7.945
# Iteration #2 - Objective function value:  0.03 - time: 6.364
# Iteration #3 - Objective function value:  0.02 - time: 7.722
# Iteration #4 - Objective function value:  0.02 - time: 6.437
# Iteration #5 - Objective function value:  0.01 - time: 7.870
# Iteration #6 - Objective function value:  0.01 - time: 6.452
# Iteration #7 - Objective function value:  0.01 - time: 8.558
# Iteration #8 - Objective function value:  0.01 - time: 6.908
# Iteration #9 - Objective function value:  0.01 - time: 8.209
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.3433743119239807
# repetition = 50
# Iteration #0 - Objective function value:  0.04 - time: 7.625
# Iteration #1 - Objective function value:  0.02 - time: 7.381
# Iteration #2 - Objective function value:  0.01 - time: 8.106
# Iteration #3 - Objective function value:  0.01 - time: 6.752
# Iteration #4 - Objective function value:  0.01 - time: 8.138
# Iteration #5 - Objective function value:  0.01 - time: 6.600
# Iteration #6 - Objective function value:  0.01 - time: 8.025
# Iteration #7 - Objective function value:  0.01 - time: 6.622
# Iteration #8 - Objective function value:  0.01 - time: 8.051
# Iteration #9 - Objective function value:  0.01 - time: 6.926
# Iteration #10 - Objective function value:  0.01 - time: 7.696
# Iteration #11 - Objective function value:  0.01 - time: 7.209
# Iteration #12 - Objective function value:  0.01 - time: 7.493
# Iteration #13 - Objective function value:  0.01 - time: 7.957
# Iteration #14 - Objective function value:  0.01 - time: 6.640
# Iteration #15 - Objective function value:  0.01 - time: 8.204
# Iteration #16 - Objective function value:  0.01 - time: 6.563
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.4037972092628479
# repetition = 51
# Iteration #0 - Objective function value:  0.08 - time: 8.013
# Iteration #1 - Objective function value:  0.06 - time: 6.639
# Iteration #2 - Objective function value:  0.06 - time: 8.034
# Iteration #3 - Objective function value:  0.05 - time: 6.655
# Iteration #4 - Objective function value:  0.03 - time: 7.917
# Iteration #5 - Objective function value:  0.03 - time: 6.991
# Iteration #6 - Objective function value:  0.03 - time: 7.376
# Iteration #7 - Objective function value:  0.03 - time: 7.358
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Mean Squared Error on Test Set: 0.23091380298137665
# repetition = 52
# Iteration #0 - Objective function value:  0.19 - time: 6.824
# Iteration #1 - Objective function value:  0.11 - time: 7.751
# Iteration #2 - Objective function value:  0.02 - time: 6.706
# Iteration #3 - Objective function value:  0.02 - time: 8.086
# Iteration #4 - Objective function value:  0.02 - time: 6.392
# Iteration #5 - Objective function value:  0.02 - time: 8.140
# Iteration #6 - Objective function value:  0.02 - time: 7.123
# Iteration #7 - Objective function value:  0.02 - time: 8.464
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.25287356972694397
# repetition = 53
# Iteration #0 - Objective function value:  0.04 - time: 7.065
# Iteration #1 - Objective function value:  0.04 - time: 7.963
# Iteration #2 - Objective function value:  0.02 - time: 7.653
# Iteration #3 - Objective function value:  0.01 - time: 7.061
# Iteration #4 - Objective function value:  0.01 - time: 8.150
# Iteration #5 - Objective function value:  0.01 - time: 6.684
# Iteration #6 - Objective function value:  0.01 - time: 7.975
# Iteration #7 - Objective function value:  0.01 - time: 6.482
# Iteration #8 - Objective function value:  0.01 - time: 8.140
# Iteration #9 - Objective function value:  0.01 - time: 6.615
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.2877539396286011
# repetition = 54
# Iteration #0 - Objective function value:  0.08 - time: 8.140
# Iteration #1 - Objective function value:  0.04 - time: 6.994
# Iteration #2 - Objective function value:  0.03 - time: 7.451
# Iteration #3 - Objective function value:  0.03 - time: 7.395
# Iteration #4 - Objective function value:  0.03 - time: 7.203
# Iteration #5 - Objective function value:  0.03 - time: 8.087
# Iteration #6 - Objective function value:  0.03 - time: 6.620
# Iteration #7 - Objective function value:  0.03 - time: 7.849
# Iteration #8 - Objective function value:  0.03 - time: 6.482
# Iteration #9 - Objective function value:  0.02 - time: 7.666
# Iteration #10 - Objective function value:  0.02 - time: 6.361
# Iteration #11 - Objective function value:  0.02 - time: 7.903
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.485362708568573
# repetition = 55
# Iteration #0 - Objective function value:  0.06 - time: 6.514
# Iteration #1 - Objective function value:  0.06 - time: 7.856
# Iteration #2 - Objective function value:  0.05 - time: 6.583
# Iteration #3 - Objective function value:  0.05 - time: 7.690
# Iteration #4 - Objective function value:  0.05 - time: 6.628
# Iteration #5 - Objective function value:  0.05 - time: 7.792
# Iteration #6 - Objective function value:  0.03 - time: 7.218
# Iteration #7 - Objective function value:  0.02 - time: 7.207
# Iteration #8 - Objective function value:  0.01 - time: 7.260
# Iteration #9 - Objective function value:  0.01 - time: 6.805
# Iteration #10 - Objective function value:  0.01 - time: 8.635
# Iteration #11 - Objective function value:  0.01 - time: 6.902
# Iteration #12 - Objective function value:  0.01 - time: 8.503
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.3196397125720978
# repetition = 56
# Iteration #0 - Objective function value:  0.12 - time: 6.859
# Iteration #1 - Objective function value:  0.04 - time: 8.554
# Iteration #2 - Objective function value:  0.02 - time: 7.316
# Iteration #3 - Objective function value:  0.01 - time: 7.583
# Iteration #4 - Objective function value:  0.01 - time: 8.117
# Iteration #5 - Objective function value:  0.01 - time: 6.854
# Iteration #6 - Objective function value:  0.01 - time: 8.396
# Iteration #7 - Objective function value:  0.01 - time: 6.796
# Iteration #8 - Objective function value:  0.01 - time: 8.107
# Iteration #9 - Objective function value:  0.01 - time: 6.639
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.2680681347846985
# repetition = 57
# Iteration #0 - Objective function value:  0.30 - time: 8.053
# Iteration #1 - Objective function value:  0.19 - time: 7.136
# Iteration #2 - Objective function value:  0.19 - time: 7.371
# Iteration #3 - Objective function value:  0.19 - time: 7.759
# Iteration #4 - Objective function value:  0.18 - time: 6.911
# Iteration #5 - Objective function value:  0.18 - time: 8.033
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.7188399434089661
# repetition = 58
# Iteration #0 - Objective function value:  0.02 - time: 6.634
# Iteration #1 - Objective function value:  0.02 - time: 8.100
# Iteration #2 - Objective function value:  0.01 - time: 6.651
# Iteration #3 - Objective function value:  0.01 - time: 8.122
# Iteration #4 - Objective function value:  0.01 - time: 6.376
# Iteration #5 - Objective function value:  0.01 - time: 7.926
# Iteration #6 - Objective function value:  0.01 - time: 6.454
# Iteration #7 - Objective function value:  0.01 - time: 7.975
# Iteration #8 - Objective function value:  0.01 - time: 6.897
# Iteration #9 - Objective function value:  0.01 - time: 7.405
# Iteration #10 - Objective function value:  0.01 - time: 7.463
# ...
# Iteration #4 - Objective function value:  0.12 - time: 8.866
# Iteration #5 - Objective function value:  0.12 - time: 6.771
# Iteration #6 - Objective function value:  0.11 - time: 7.528
# Iteration #7 - Objective function value:  0.11 - time: 6.941
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Mean Squared Error on Test Set: 0.04149104654788971
# repetition = 83
# Iteration #0 - Objective function value:  0.11 - time: 7.403
# Iteration #1 - Objective function value:  0.08 - time: 7.535
# Iteration #2 - Objective function value:  0.02 - time: 6.734
# Iteration #3 - Objective function value:  0.02 - time: 7.868
# Iteration #4 - Objective function value:  0.02 - time: 6.371
# Iteration #5 - Objective function value:  0.02 - time: 7.925
# Iteration #6 - Objective function value:  0.02 - time: 6.469
# Iteration #7 - Objective function value:  0.02 - time: 8.120
# Iteration #8 - Objective function value:  0.02 - time: 6.962
# Iteration #9 - Objective function value:  0.02 - time: 8.174
# Iteration #10 - Objective function value:  0.02 - time: 7.217
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Mean Squared Error on Test Set: 0.26820892095565796
# repetition = 84
# Iteration #0 - Objective function value:  0.19 - time: 8.027
# Iteration #1 - Objective function value:  0.12 - time: 7.857
# Iteration #2 - Objective function value:  0.03 - time: 6.969
# Iteration #3 - Objective function value:  0.03 - time: 8.059
# Iteration #4 - Objective function value:  0.02 - time: 6.593
# Iteration #5 - Objective function value:  0.02 - time: 8.177
# Iteration #6 - Objective function value:  0.02 - time: 6.561
# Iteration #7 - Objective function value:  0.02 - time: 8.216
# Iteration #8 - Objective function value:  0.02 - time: 6.582
# Iteration #9 - Objective function value:  0.01 - time: 7.989
# Iteration #10 - Objective function value:  0.01 - time: 6.939
# Iteration #11 - Objective function value:  0.01 - time: 7.595
# Iteration #12 - Objective function value:  0.01 - time: 7.464
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Mean Squared Error on Test Set: 0.3458820879459381
# repetition = 85
# Iteration #0 - Objective function value:  0.11 - time: 6.905
# Iteration #1 - Objective function value:  0.05 - time: 7.999
# Iteration #2 - Objective function value:  0.03 - time: 6.521
# Iteration #3 - Objective function value:  0.03 - time: 8.055
# Iteration #4 - Objective function value:  0.03 - time: 6.335
# Iteration #5 - Objective function value:  0.03 - time: 7.873
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.18607285618782043
# repetition = 86
# Iteration #0 - Objective function value:  0.04 - time: 6.640
# Iteration #1 - Objective function value:  0.04 - time: 8.167
# Iteration #2 - Objective function value:  0.01 - time: 6.261
# Iteration #3 - Objective function value:  0.01 - time: 7.959
# Iteration #4 - Objective function value:  0.01 - time: 6.887
# Iteration #5 - Objective function value:  0.01 - time: 7.669
# Iteration #6 - Objective function value:  0.01 - time: 7.111
# Iteration #7 - Objective function value:  0.01 - time: 7.265
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.39340850710868835
# repetition = 87
# Iteration #0 - Objective function value:  0.05 - time: 8.103
# Iteration #1 - Objective function value:  0.05 - time: 6.447
# Iteration #2 - Objective function value:  0.05 - time: 7.970
# Iteration #3 - Objective function value:  0.05 - time: 6.780
# Iteration #4 - Objective function value:  0.05 - time: 8.254
# Iteration #5 - Objective function value:  0.04 - time: 7.019
# Iteration #6 - Objective function value:  0.04 - time: 8.230
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.12074093520641327
# repetition = 88
# Iteration #0 - Objective function value:  0.04 - time: 7.289
# Iteration #1 - Objective function value:  0.03 - time: 7.511
# Iteration #2 - Objective function value:  0.03 - time: 8.087
# Iteration #3 - Objective function value:  0.02 - time: 6.766
# Iteration #4 - Objective function value:  0.02 - time: 8.149
# Iteration #5 - Objective function value:  0.02 - time: 6.752
# Iteration #6 - Objective function value:  0.02 - time: 8.046
# Iteration #7 - Objective function value:  0.02 - time: 6.612
# Iteration #8 - Objective function value:  0.02 - time: 8.191
# Iteration #9 - Objective function value:  0.02 - time: 9.420
# Iteration #10 - Objective function value:  0.02 - time: 9.855
# Iteration #11 - Objective function value:  0.01 - time: 11.062
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Mean Squared Error on Test Set: 0.2676506042480469
# repetition = 89
# Iteration #0 - Objective function value:  0.05 - time: 9.738
# Iteration #1 - Objective function value:  0.05 - time: 9.419
# Iteration #2 - Objective function value:  0.01 - time: 10.354
# Iteration #3 - Objective function value:  0.01 - time: 9.203
# Iteration #4 - Objective function value:  0.01 - time: 10.403
# Iteration #5 - Objective function value:  0.01 - time: 10.865
# Iteration #6 - Objective function value:  0.01 - time: 9.036
# Iteration #7 - Objective function value:  0.01 - time: 10.782
# Iteration #8 - Objective function value:  0.01 - time: 10.276
# Iteration #9 - Objective function value:  0.01 - time: 9.013
# Iteration #10 - Objective function value:  0.01 - time: 10.182
# Iteration #11 - Objective function value:  0.01 - time: 9.841
# Iteration #12 - Objective function value:  0.01 - time: 7.958
# Iteration #13 - Objective function value:  0.01 - time: 7.993
# Iteration #14 - Objective function value:  0.01 - time: 6.333
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.3114779591560364
# repetition = 90
# Iteration #0 - Objective function value:  0.27 - time: 7.836
# Iteration #1 - Objective function value:  0.05 - time: 6.486
# Iteration #2 - Objective function value:  0.04 - time: 7.866
# Iteration #3 - Objective function value:  0.01 - time: 6.675
# Iteration #4 - Objective function value:  0.01 - time: 8.371
# Iteration #5 - Objective function value:  0.01 - time: 7.489
# Iteration #6 - Objective function value:  0.01 - time: 7.713
# Iteration #7 - Objective function value:  0.01 - time: 8.209
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.30773308873176575
# repetition = 91
# Iteration #0 - Objective function value:  0.09 - time: 6.756
# Iteration #1 - Objective function value:  0.02 - time: 8.150
# Iteration #2 - Objective function value:  0.02 - time: 6.708
# Iteration #3 - Objective function value:  0.02 - time: 8.043
# Iteration #4 - Objective function value:  0.02 - time: 6.574
# Iteration #5 - Objective function value:  0.02 - time: 8.002
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.3755338788032532
# repetition = 92
# Iteration #0 - Objective function value:  0.21 - time: 7.287
# Iteration #1 - Objective function value:  0.12 - time: 7.285
# Iteration #2 - Objective function value:  0.01 - time: 7.573
# Iteration #3 - Objective function value:  0.01 - time: 6.874
# Iteration #4 - Objective function value:  0.01 - time: 8.173
# Iteration #5 - Objective function value:  0.01 - time: 6.510
# Iteration #6 - Objective function value:  0.01 - time: 7.873
# Iteration #7 - Objective function value:  0.01 - time: 6.616
# Iteration #8 - Objective function value:  0.01 - time: 8.002
# Iteration #9 - Objective function value:  0.01 - time: 6.423
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.3533170223236084
# repetition = 93
# Iteration #0 - Objective function value:  0.06 - time: 7.814
# Iteration #1 - Objective function value:  0.06 - time: 6.327
# Iteration #2 - Objective function value:  0.05 - time: 8.020
# Iteration #3 - Objective function value:  0.05 - time: 6.844
# Iteration #4 - Objective function value:  0.05 - time: 7.497
# Iteration #5 - Objective function value:  0.05 - time: 7.115
# Iteration #6 - Objective function value:  0.05 - time: 7.173
# Iteration #7 - Objective function value:  0.05 - time: 7.976
# Iteration #8 - Objective function value:  0.05 - time: 6.412
# Iteration #9 - Objective function value:  0.05 - time: 7.649
# Iteration #10 - Objective function value:  0.05 - time: 6.411
# Iteration #11 - Objective function value:  0.05 - time: 7.753
# Iteration #12 - Objective function value:  0.05 - time: 6.399
# Iteration #13 - Objective function value:  0.05 - time: 7.776
# Iteration #14 - Objective function value:  0.05 - time: 7.068
# Iteration #15 - Objective function value:  0.05 - time: 8.234
# Iteration #16 - Objective function value:  0.04 - time: 7.083
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Mean Squared Error on Test Set: 0.10523796081542969
# repetition = 94
# Iteration #0 - Objective function value:  0.03 - time: 8.318
# Iteration #1 - Objective function value:  0.03 - time: 8.103
# Iteration #2 - Objective function value:  0.02 - time: 6.857
# Iteration #3 - Objective function value:  0.01 - time: 8.026
# Iteration #4 - Objective function value:  0.01 - time: 6.529
# Iteration #5 - Objective function value:  0.01 - time: 7.905
# Iteration #6 - Objective function value:  0.01 - time: 6.698
# Iteration #7 - Objective function value:  0.01 - time: 7.750
# Iteration #8 - Objective function value:  0.01 - time: 6.610
# Iteration #9 - Objective function value:  0.01 - time: 7.841
# Iteration #10 - Objective function value:  0.01 - time: 6.797
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Mean Squared Error on Test Set: 0.37306535243988037
# repetition = 95
# Iteration #0 - Objective function value:  0.17 - time: 7.584
# Iteration #1 - Objective function value:  0.16 - time: 7.110
# Iteration #2 - Objective function value:  0.07 - time: 7.329
# Iteration #3 - Objective function value:  0.03 - time: 7.586
# Iteration #4 - Objective function value:  0.02 - time: 6.811
# Iteration #5 - Objective function value:  0.01 - time: 8.006
# Iteration #6 - Objective function value:  0.01 - time: 6.559
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.2705869972705841
# repetition = 96
# Iteration #0 - Objective function value:  0.06 - time: 7.907
# Iteration #1 - Objective function value:  0.06 - time: 6.429
# Iteration #2 - Objective function value:  0.05 - time: 8.081
# Iteration #3 - Objective function value:  0.03 - time: 6.386
# Iteration #4 - Objective function value:  0.02 - time: 8.124
# Iteration #5 - Objective function value:  0.02 - time: 6.484
# Iteration #6 - Objective function value:  0.01 - time: 7.995
# Iteration #7 - Objective function value:  0.01 - time: 6.649
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Mean Squared Error on Test Set: 0.3192640244960785
# repetition = 97
# Iteration #0 - Objective function value:  0.14 - time: 7.582
# Iteration #1 - Objective function value:  0.02 - time: 6.818
# Iteration #2 - Objective function value:  0.02 - time: 7.163
# Iteration #3 - Objective function value:  0.01 - time: 7.518
# Iteration #4 - Objective function value:  0.01 - time: 6.846
# Iteration #5 - Objective function value:  0.01 - time: 8.463
# Iteration #6 - Objective function value:  0.01 - time: 6.704
# Iteration #7 - Objective function value:  0.01 - time: 8.209
# Iteration #8 - Objective function value:  0.01 - time: 6.803
# Iteration #9 - Objective function value:  0.01 - time: 8.283
# Iteration #10 - Objective function value:  0.01 - time: 7.093
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Mean Squared Error on Test Set: 0.33304741978645325
# repetition = 98
# Iteration #0 - Objective function value:  0.16 - time: 7.858
# Iteration #1 - Objective function value:  0.04 - time: 8.018
# Iteration #2 - Objective function value:  0.04 - time: 6.921
# Iteration #3 - Objective function value:  0.04 - time: 8.264
# Iteration #4 - Objective function value:  0.03 - time: 6.625
# Iteration #5 - Objective function value:  0.03 - time: 8.103
# Iteration #6 - Objective function value:  0.03 - time: 6.637
# Iteration #7 - Objective function value:  0.03 - time: 8.244
# Iteration #8 - Objective function value:  0.03 - time: 6.605
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Mean Squared Error on Test Set: 0.2221224308013916
# repetition = 99
# [[50, 11, 1.5, 81.71762062400012, 0.30234653], [50, 6, 1.5, 43.47091290099888, 0.28448382], [50, 7, 1.5, 51.026595640998494, 0.07203647], [50, 11, 1.5, 83.67776677099937, 0.37793943], [50, 8, 1.5, 58.81853919800051, 0.5936553], [50, 7, 1.5, 49.49918964099925, 0.86458504], [50, 12, 1.5, 90.02919332700003, 0.30863848], [50, 14, 1.5, 101.15926232899983, 0.098081276], [50, 15, 1.5, 109.42078413099989, 0.2661016], [50, 15, 1.5, 111.29928144699988, 0.28442782], [50, 8, 1.5, 58.85408455199831, 0.30434704], [50, 17, 1.5, 124.80741599099929, 0.2562349], [50, 8, 1.5, 57.817009809999945, 0.1303886], [50, 8, 1.5, 57.71057038500112, 0.15079756], [50, 10, 1.5, 72.36127040500105, 0.26396465], [50, 12, 1.5, 90.74175565100086, 0.3784812], [50, 8, 1.5, 59.01224498500051, 0.22683968], [50, 17, 1.5, 123.02182878999884, 0.37323245], [50, 6, 1.5, 44.74450714699924, 0.42030138], [50, 8, 1.5, 60.72706739100067, 0.30094093], [50, 9, 1.5, 64.231568444, 0.44456217], [50, 14, 1.5, 102.6818542509991, 0.2837397], [50, 14, 1.5, 102.59425764000116, 0.7521651], [50, 15, 1.5, 107.76682328700008, 0.2639441], [50, 7, 1.5, 52.85653561199979, 0.32042447], [50, 11, 1.5, 81.81330576400069, 0.15670888], [50, 11, 1.5, 79.54641690599965, 0.4980109], [50, 7, 1.5, 51.561968882000656, 0.21419786], [50, 13, 1.5, 95.37711115999991, 0.33846506], [50, 15, 1.5, 107.95340074399974, 0.6193198], [50, 7, 1.5, 51.689280107999366, 0.39803275], [50, 15, 1.5, 111.7884219940006, 0.23022602], [50, 10, 1.5, 71.53815455800031, 0.3668421], [50, 17, 1.5, 125.29397358700044, 0.17327787], [50, 16, 1.5, 116.55867169500016, 0.3024267], [50, 16, 1.5, 117.12951701699967, 0.354841], [50, 8, 1.5, 59.7258736849999, 0.33538377], [50, 6, 1.5, 43.558286710000175, 0.3966325], [50, 8, 1.5, 57.50774972999898, 0.28430822], [50, 12, 1.5, 90.75856358599958, 0.3799416], [50, 12, 1.5, 87.61330072999954, 0.35476288], [50, 17, 1.5, 124.54374132399971, 0.30652267], [50, 6, 1.5, 46.39939318600045, 0.33960703], [50, 13, 1.5, 96.00646541300011, 0.24512419], [50, 13, 1.5, 94.70927329799997, 0.22530016], [50, 10, 1.5, 76.01734309399944, 0.17624894], [50, 13, 1.5, 95.08284394500151, 0.26371887], [50, 9, 1.5, 64.66052960199886, 0.31938887], [50, 13, 1.5, 98.30061206900064, 0.3740403], [50, 15, 1.5, 110.6106263720012, 0.30922186], [50, 10, 1.5, 72.98623724800018, 0.3433743], [50, 17, 1.5, 125.99365964699973, 0.4037972], [50, 8, 1.5, 58.98585586700028, 0.2309138], [50, 8, 1.5, 59.486843949000104, 0.25287357], [50, 10, 1.5, 73.79197670800022, 0.28775394], [50, 12, 1.5, 88.15487625300011, 0.4853627], [50, 13, 1.5, 95.60031802200137, 0.3196397], [50, 10, 1.5, 75.22540457899959, 0.26806813], [50, 6, 1.5, 45.26428908200069, 0.71883994], [50, 15, 1.5, 109.4531802090005, 0.35634857], [50, 11, 1.5, 83.68839160899915, 0.3595253], [50, 17, 1.5, 124.18737723899903, 0.35230422], [50, 13, 1.5, 96.72789863400249, 0.20875655], [50, 10, 1.5, 76.39825474700046, 0.49522847], [50, 8, 1.5, 58.669744355996954, 0.3276154], [50, 12, 1.5, 89.31808735799859, 0.22049625], [50, 11, 1.5, 83.34049123600198, 0.29127088], [50, 15, 1.5, 111.39824285400027, 0.4102578], [50, 12, 1.5, 90.99722024799848, 0.15895537], [50, 14, 1.5, 104.00123562900262, 0.2834752], [50, 17, 1.5, 124.97434273899853, 0.36591056], [50, 8, 1.5, 61.799416150999605, 0.3631854], [50, 8, 1.5, 58.434369730999606, 0.6525045], [50, 6, 1.5, 44.1227761500013, 0.33240885], [50, 6, 1.5, 44.22705513800247, 0.5784583], [50, 12, 1.5, 89.73831984299977, 0.30306056], [50, 9, 1.5, 67.32693732699772, 0.41061273], [50, 12, 1.5, 88.4187047560008, 0.33116153], [50, 12, 1.5, 89.22073956699751, 0.43651238], [50, 10, 1.5, 75.64461946499796, 0.36904645], [50, 16, 1.5, 115.69039611900007, 0.36041424], [50, 9, 1.5, 67.52906571600033, 0.49098432], [50, 9, 1.5, 66.8315613349987, 0.35171574], [50, 8, 1.5, 58.75552094599698, 0.041491047], [50, 11, 1.5, 80.78390305299763, 0.26820892], [50, 13, 1.5, 97.03543497899955, 0.3458821], [50, 6, 1.5, 43.688767014002224, 0.18607286], [50, 8, 1.5, 57.96322228500139, 0.3934 ...

# %%
df_woa = pd.DataFrame(data = woa_variables)

print(df_woa)
# Out:
#      0   1    2          3         4
# 0   50  11  1.5  81.717621  0.302347
# 1   50   6  1.5  43.470913  0.284484
# 2   50   7  1.5  51.026596  0.072036
# 3   50  11  1.5  83.677767  0.377939
# 4   50   8  1.5  58.818539  0.593655
# ..  ..  ..  ...        ...       ...
# 95  50  11  1.5  81.436267  0.373065
# 96  50   7  1.5  50.987470  0.270587
# 97  50   8  1.5  58.060773  0.319264
# 98  50  11  1.5  81.486514  0.333047
# 99  50   9  1.5  67.278219  0.222122
#
# [100 rows x 5 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
with open('/content/drive/MyDrive/TESI/Colab Notebooks/IT 6-18, POP=50, X_MAX=1.5/WOA_SPHFUN ITERATION 6-18.txt', 'a') as file:
        df_woa.to_csv(file, sep = '\t', index=False, mode= 'a', header = ['x','x','x','x','x'])

# %%
#@title Class PSO

class PSO(Meta):
    def __init__(self, net_structure):
        super().__init__(net_structure)
        self.w  = 0.3 # inertia_param
        self.c1 = 1.5 # cognitive_param
        self.c2 = 1.5 # social_param

    def set_options(self, inertia_param = 0.3,
                    cognitive_param = 1.5,
                    social_param = 1.5):
        self.w  = inertia_param
        self.c1 = cognitive_param
        self.c2 = social_param

    def set_max_v(self, max_v):
        self.max_v = max_v

    def set_max_x(self, max_x):
        self.max_x = max_x
    # updating speeds by calculating the three basic components: inertia, cogninitve_component and social_component
    def update_velocity(self, position, velocity, best_position, global_best_position):
        inertia = self.w * velocity
        cognitive_component = self.c1 *2* np.random.rand(1, len(position)) * (best_position - position)
        social_component = self.c2 *2* np.random.rand(1, len(position)) * (global_best_position - position)
        new_velocity = inertia + cognitive_component + social_component
        return new_velocity

    def optimize(self):
        particles  = np.random.uniform(low=-self.max_x, high=self.max_x, size=(self.population_size, self.num_parameters))
        velocities = np.random.uniform(low=-self.max_v, high=self.max_v, size=(self.population_size, self.num_parameters))
        best_positions = np.copy(particles)
        best_scores = np.array([self.num_parameters] * self.population_size)
        global_best_position = None
        global_best_score = 1e10
        nl = len(self.model.layers)

        for iteration in range(self.num_iterations):
            tic_global = time.perf_counter()

            for i in range(self.population_size):
                particle = particles[i,]

                wbindex = 0

                for p in range(0, nl):
                  W = particle[wbindex:(wbindex + self.model.layers[p].input.shape[1] * self.model.layers[p].output.shape[1])]
                  b = particle[(wbindex + self.model.layers[p].input.shape[1] * self.model.layers[p].output.shape[1]):(wbindex + self.model.layers[p].count_params())]
                  self.model.layers[p].set_weights([W.reshape(self.model.layers[p].input.shape[1], self.model.layers[p].output.shape[1]), b])
                  wbindex = (wbindex + self.model.layers[p].count_params())

                fitness = self.objective_function(n_samples = 1000)

                if  fitness < best_scores[i]:
                    best_scores[i] = fitness
                    best_positions[i] = np.copy(particles[i])

                if  fitness < global_best_score:
                    global_best_score = fitness
                    global_best_position = np.copy(particles[i])

                velocities[i] = self.update_velocity(particles[i], velocities[i], best_positions[i], global_best_position)
                particles[i] += velocities[i]
            # check that the adjourned positions are not outside the domain and velocities are not over the limit
            velocities = np.minimum(velocities,  self.max_v)
            velocities = np.maximum(velocities, -self.max_v)
            particles  = np.minimum(particles,  self.max_x)
            particles  = np.maximum(particles, -self.max_x)

            toc_global = time.perf_counter()
            print("Iteration #%d - Objective function value: %5.2f - time: %0.3f" % (iteration, global_best_score, toc_global - tic_global))

            if (global_best_score == 0):
                break
        return global_best_position

    def predict(self, x = None):
        return self.model.predict(x)

# %%
#@title Code for traing and test with PSO

net = NetStructure(input_dim=2, output_dim=1)
net.add_hidden(hidden_dim=5)

met = PSO(net)
met.set_population_size(50)
met.set_max_v(0.3)
met.set_max_x(1.5)

repetitions = 30
pso_variables = []

sample_size = 1000
domain = [-1, 1]

# TRAIN
for i in range(repetitions):
    x = np.random.randint(6, 18)
    met.set_num_iterations(x)
    time_start = time.perf_counter()
    optimized_params = met.optimize()
    time_end = time.perf_counter()
    time_pso = time_end - time_start
    met.update_model_with_parameters(optimized_params)

    X_test = np.random.uniform(low=1, high=2, size=(sample_size, 2))

    # TEST
    y_pred_test = met.predict(X_test)
    mse_test = np.mean((y_pred_test.flatten() - y_pred_test)**2)
    print(f"Mean Squared Error on Test Set: {mse_test}")

    variables = [[met.population_size, x, met.max_v, met.max_x, time_pso, mse_test]]
    pso_variables = pso_variables + variables

    print("repetition = ", i)

print(pso_variables)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Iteration #0 - Objective function value:  0.12 - time: 15.829
# Iteration #1 - Objective function value:  0.11 - time: 9.055
# Iteration #2 - Objective function value:  0.04 - time: 7.405
# Iteration #3 - Objective function value:  0.04 - time: 6.223
# Iteration #4 - Objective function value:  0.04 - time: 7.309
# Iteration #5 - Objective function value:  0.04 - time: 6.165
# Iteration #6 - Objective function value:  0.04 - time: 7.239
# Iteration #7 - Objective function value:  0.04 - time: 6.090
# Iteration #8 - Objective function value:  0.04 - time: 7.831
# Iteration #9 - Objective function value:  0.04 - time: 6.687
# Iteration #10 - Objective function value:  0.04 - time: 7.086
# Iteration #11 - Objective function value:  0.04 - time: 7.594
# Iteration #12 - Objective function value:  0.04 - time: 6.232
# Iteration #13 - Objective function value:  0.04 - time: 7.264
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.1275331974029541
# repetition =  0
# Iteration #0 - Objective function value:  0.05 - time: 6.215
# Iteration #1 - Objective function value:  0.02 - time: 7.169
# Iteration #2 - Objective function value:  0.02 - time: 6.154
# Iteration #3 - Objective function value:  0.01 - time: 6.985
# Iteration #4 - Objective function value:  0.01 - time: 6.160
# Iteration #5 - Objective function value:  0.01 - time: 7.327
# Iteration #6 - Objective function value:  0.01 - time: 6.204
# Iteration #7 - Objective function value:  0.01 - time: 7.327
# Iteration #8 - Objective function value:  0.01 - time: 6.360
# Iteration #9 - Objective function value:  0.01 - time: 7.464
# Iteration #10 - Objective function value:  0.01 - time: 7.248
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.3282943665981293
# repetition =  1
# Iteration #0 - Objective function value:  0.13 - time: 6.208
# Iteration #1 - Objective function value:  0.13 - time: 7.188
# Iteration #2 - Objective function value:  0.03 - time: 6.136
# Iteration #3 - Objective function value:  0.03 - time: 7.122
# Iteration #4 - Objective function value:  0.03 - time: 6.193
# Iteration #5 - Objective function value:  0.03 - time: 7.232
# Iteration #6 - Objective function value:  0.03 - time: 6.188
# Iteration #7 - Objective function value:  0.02 - time: 7.104
# Iteration #8 - Objective function value:  0.02 - time: 6.177
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.31733226776123047
# repetition =  2
# Iteration #0 - Objective function value:  0.11 - time: 7.201
# Iteration #1 - Objective function value:  0.11 - time: 6.422
# Iteration #2 - Objective function value:  0.11 - time: 7.041
# Iteration #3 - Objective function value:  0.11 - time: 6.443
# Iteration #4 - Objective function value:  0.10 - time: 6.841
# Iteration #5 - Objective function value:  0.10 - time: 6.677
# Iteration #6 - Objective function value:  0.10 - time: 6.486
# Iteration #7 - Objective function value:  0.10 - time: 7.178
# Iteration #8 - Objective function value:  0.10 - time: 6.122
# Iteration #9 - Objective function value:  0.10 - time: 7.154
# Iteration #10 - Objective function value:  0.10 - time: 6.199
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.45711106061935425
# repetition =  3
# Iteration #0 - Objective function value:  0.06 - time: 7.184
# Iteration #1 - Objective function value:  0.06 - time: 6.185
# Iteration #2 - Objective function value:  0.02 - time: 7.099
# Iteration #3 - Objective function value:  0.02 - time: 6.135
# Iteration #4 - Objective function value:  0.02 - time: 7.350
# Iteration #5 - Objective function value:  0.02 - time: 7.749
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Mean Squared Error on Test Set: 0.23362964391708374
# repetition =  4
# Iteration #0 - Objective function value:  0.18 - time: 7.609
# Iteration #1 - Objective function value:  0.17 - time: 7.023
# Iteration #2 - Objective function value:  0.14 - time: 6.546
# Iteration #3 - Objective function value:  0.03 - time: 7.196
# Iteration #4 - Objective function value:  0.03 - time: 6.202
# Iteration #5 - Objective function value:  0.02 - time: 7.487
# Iteration #6 - Objective function value:  0.02 - time: 6.709
# Iteration #7 - Objective function value:  0.02 - time: 7.298
# Iteration #8 - Objective function value:  0.02 - time: 6.214
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.26101115345954895
# repetition =  5
# Iteration #0 - Objective function value:  0.26 - time: 7.213
# Iteration #1 - Objective function value:  0.11 - time: 6.436
# Iteration #2 - Objective function value:  0.05 - time: 6.951
# Iteration #3 - Objective function value:  0.05 - time: 7.039
# Iteration #4 - Objective function value:  0.04 - time: 6.552
# Iteration #5 - Objective function value:  0.03 - time: 7.258
# Iteration #6 - Objective function value:  0.03 - time: 6.300
# Iteration #7 - Objective function value:  0.03 - time: 7.324
# Iteration #8 - Objective function value:  0.03 - time: 6.293
# Iteration #9 - Objective function value:  0.03 - time: 7.394
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.42997443675994873
# repetition =  6
# Iteration #0 - Objective function value:  0.20 - time: 6.320
# Iteration #1 - Objective function value:  0.04 - time: 7.227
# Iteration #2 - Objective function value:  0.04 - time: 6.374
# Iteration #3 - Objective function value:  0.04 - time: 7.228
# Iteration #4 - Objective function value:  0.04 - time: 7.124
# Iteration #5 - Objective function value:  0.04 - time: 6.384
# Iteration #6 - Objective function value:  0.04 - time: 7.167
# Iteration #7 - Objective function value:  0.04 - time: 6.173
# Iteration #8 - Objective function value:  0.04 - time: 7.329
# Iteration #9 - Objective function value:  0.04 - time: 6.374
# Iteration #10 - Objective function value:  0.04 - time: 7.232
# Iteration #11 - Objective function value:  0.04 - time: 6.296
# Iteration #12 - Objective function value:  0.04 - time: 7.419
# Iteration #13 - Objective function value:  0.04 - time: 6.168
# Iteration #14 - Objective function value:  0.04 - time: 7.196
# Iteration #15 - Objective function value:  0.04 - time: 6.572
# Iteration #16 - Objective function value:  0.04 - time: 6.814
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.47921687364578247
# repetition =  7
# Iteration #0 - Objective function value:  0.26 - time: 7.475
# Iteration #1 - Objective function value:  0.05 - time: 8.763
# Iteration #2 - Objective function value:  0.05 - time: 9.107
# Iteration #3 - Objective function value:  0.05 - time: 10.060
# Iteration #4 - Objective function value:  0.05 - time: 7.963
# Iteration #5 - Objective function value:  0.04 - time: 10.585
# Iteration #6 - Objective function value:  0.04 - time: 8.900
# Iteration #7 - Objective function value:  0.04 - time: 8.821
# Iteration #8 - Objective function value:  0.04 - time: 9.115
# Iteration #9 - Objective function value:  0.04 - time: 10.342
# Iteration #10 - Objective function value:  0.04 - time: 8.391
# Iteration #11 - Objective function value:  0.04 - time: 9.878
# Iteration #12 - Objective function value:  0.04 - time: 9.432
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Mean Squared Error on Test Set: 0.507042407989502
# repetition =  8
# Iteration #0 - Objective function value:  0.13 - time: 9.336
# Iteration #1 - Objective function value:  0.13 - time: 9.196
# Iteration #2 - Objective function value:  0.13 - time: 9.577
# Iteration #3 - Objective function value:  0.13 - time: 9.964
# Iteration #4 - Objective function value:  0.13 - time: 6.296
# Iteration #5 - Objective function value:  0.13 - time: 7.236
# Iteration #6 - Objective function value:  0.13 - time: 6.254
# Iteration #7 - Objective function value:  0.13 - time: 7.177
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 1.0822112560272217
# repetition =  9
# Iteration #0 - Objective function value:  0.13 - time: 6.372
# Iteration #1 - Objective function value:  0.09 - time: 7.303
# Iteration #2 - Objective function value:  0.04 - time: 6.299
# Iteration #3 - Objective function value:  0.04 - time: 7.362
# Iteration #4 - Objective function value:  0.04 - time: 6.887
# Iteration #5 - Objective function value:  0.04 - time: 6.705
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.454950213432312
# repetition =  10
# Iteration #0 - Objective function value:  0.04 - time: 7.328
# Iteration #1 - Objective function value:  0.04 - time: 6.351
# Iteration #2 - Objective function value:  0.03 - time: 7.532
# Iteration #3 - Objective function value:  0.03 - time: 6.198
# Iteration #4 - Objective function value:  0.03 - time: 7.179
# Iteration #5 - Objective function value:  0.03 - time: 6.267
# Iteration #6 - Objective function value:  0.03 - time: 7.443
# Iteration #7 - Objective function value:  0.03 - time: 6.239
# Iteration #8 - Objective function value:  0.03 - time: 7.471
# Iteration #9 - Objective function value:  0.03 - time: 6.709
# Iteration #10 - Objective function value:  0.03 - time: 6.660
# Iteration #11 - Objective function value:  0.03 - time: 7.583
# Iteration #12 - Objective function value:  0.03 - time: 6.248
# Iteration #13 - Objective function value:  0.03 - time: 7.792
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.5229173898696899
# repetition =  11
# Iteration #0 - Objective function value:  0.07 - time: 6.438
# Iteration #1 - Objective function value:  0.07 - time: 7.530
# Iteration #2 - Objective function value:  0.02 - time: 6.242
# Iteration #3 - Objective function value:  0.02 - time: 7.479
# Iteration #4 - Objective function value:  0.02 - time: 7.291
# Iteration #5 - Objective function value:  0.02 - time: 8.699
# Iteration #6 - Objective function value:  0.02 - time: 8.436
# Iteration #7 - Objective function value:  0.02 - time: 6.402
# Iteration #8 - Objective function value:  0.02 - time: 7.471
# Iteration #9 - Objective function value:  0.02 - time: 6.401
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Mean Squared Error on Test Set: 0.21881920099258423
# repetition =  12
# Iteration #0 - Objective function value:  0.17 - time: 7.374
# Iteration #1 - Objective function value:  0.08 - time: 6.930
# Iteration #2 - Objective function value:  0.08 - time: 6.641
# Iteration #3 - Objective function value:  0.08 - time: 7.399
# Iteration #4 - Objective function value:  0.08 - time: 6.366
# Iteration #5 - Objective function value:  0.08 - time: 7.283
# Iteration #6 - Objective function value:  0.07 - time: 6.313
# Iteration #7 - Objective function value:  0.07 - time: 7.370
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.6407799124717712
# repetition =  13
# Iteration #0 - Objective function value:  0.58 - time: 6.290
# Iteration #1 - Objective function value:  0.19 - time: 7.188
# Iteration #2 - Objective function value:  0.02 - time: 6.522
# Iteration #3 - Objective function value:  0.02 - time: 7.258
# Iteration #4 - Objective function value:  0.02 - time: 7.155
# Iteration #5 - Objective function value:  0.02 - time: 6.831
# Iteration #6 - Objective function value:  0.02 - time: 7.300
# Iteration #7 - Objective function value:  0.02 - time: 6.429
# Iteration #8 - Objective function value:  0.02 - time: 7.342
# Iteration #9 - Objective function value:  0.02 - time: 6.415
# Iteration #10 - Objective function value:  0.02 - time: 7.372
# Iteration #11 - Objective function value:  0.02 - time: 6.402
# Iteration #12 - Objective function value:  0.02 - time: 7.361
# Iteration #13 - Objective function value:  0.02 - time: 6.670
# Iteration #14 - Objective function value:  0.02 - time: 6.905
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.4592427611351013
# repetition =  14
# Iteration #0 - Objective function value:  0.08 - time: 7.656
# Iteration #1 - Objective function value:  0.08 - time: 6.518
# Iteration #2 - Objective function value:  0.08 - time: 7.301
# Iteration #3 - Objective function value:  0.06 - time: 6.378
# Iteration #4 - Objective function value:  0.06 - time: 7.400
# Iteration #5 - Objective function value:  0.06 - time: 6.378
# Iteration #6 - Objective function value:  0.06 - time: 7.345
# Iteration #7 - Objective function value:  0.06 - time: 6.339
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.25576791167259216
# repetition =  15
# Iteration #0 - Objective function value:  0.06 - time: 7.442
# Iteration #1 - Objective function value:  0.03 - time: 6.754
# Iteration #2 - Objective function value:  0.03 - time: 6.897
# Iteration #3 - Objective function value:  0.03 - time: 7.428
# Iteration #4 - Objective function value:  0.03 - time: 6.394
# Iteration #5 - Objective function value:  0.03 - time: 7.417
# Iteration #6 - Objective function value:  0.03 - time: 6.294
# Iteration #7 - Objective function value:  0.03 - time: 7.354
# Iteration #8 - Objective function value:  0.03 - time: 6.428
# Iteration #9 - Objective function value:  0.03 - time: 7.572
# Iteration #10 - Objective function value:  0.03 - time: 6.562
# Iteration #11 - Objective function value:  0.03 - time: 7.169
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.20827853679656982
# repetition =  16
# Iteration #0 - Objective function value:  0.05 - time: 7.337
# Iteration #1 - Objective function value:  0.05 - time: 6.286
# Iteration #2 - Objective function value:  0.05 - time: 7.270
# Iteration #3 - Objective function value:  0.05 - time: 6.287
# Iteration #4 - Objective function value:  0.05 - time: 7.498
# Iteration #5 - Objective function value:  0.05 - time: 6.268
# Iteration #6 - Objective function value:  0.05 - time: 7.463
# Iteration #7 - Objective function value:  0.05 - time: 6.391
# Iteration #8 - Objective function value:  0.05 - time: 7.307
# Iteration #9 - Objective function value:  0.05 - time: 6.803
# Iteration #10 - Objective function value:  0.05 - time: 6.981
# Iteration #11 - Objective function value:  0.05 - time: 7.203
# Iteration #12 - Objective function value:  0.05 - time: 6.227
# Iteration #13 - Objective function value:  0.05 - time: 7.377
# Iteration #14 - Objective function value:  0.05 - time: 6.219
# Iteration #15 - Objective function value:  0.05 - time: 7.674
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.21484388411045074
# repetition =  17
# Iteration #0 - Objective function value:  0.15 - time: 6.629
# Iteration #1 - Objective function value:  0.12 - time: 7.483
# Iteration #2 - Objective function value:  0.07 - time: 6.750
# Iteration #3 - Objective function value:  0.07 - time: 7.112
# Iteration #4 - Objective function value:  0.07 - time: 7.464
# Iteration #5 - Objective function value:  0.07 - time: 6.420
# Iteration #6 - Objective function value:  0.07 - time: 7.570
# Iteration #7 - Objective function value:  0.07 - time: 6.413
# Iteration #8 - Objective function value:  0.07 - time: 7.427
# Iteration #9 - Objective function value:  0.07 - time: 6.519
# Iteration #10 - Objective function value:  0.07 - time: 7.373
# Iteration #11 - Objective function value:  0.07 - time: 6.752
# Iteration #12 - Objective function value:  0.07 - time: 6.993
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.541024923324585
# repetition =  18
# Iteration #0 - Objective function value:  0.14 - time: 7.119
# Iteration #1 - Objective function value:  0.14 - time: 6.516
# Iteration #2 - Objective function value:  0.03 - time: 7.199
# Iteration #3 - Objective function value:  0.03 - time: 6.460
# Iteration #4 - Objective function value:  0.03 - time: 7.409
# Iteration #5 - Objective function value:  0.03 - time: 6.270
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.30800148844718933
# repetition =  19
# Iteration #0 - Objective function value:  0.03 - time: 7.420
# Iteration #1 - Objective function value:  0.03 - time: 6.326
# Iteration #2 - Objective function value:  0.03 - time: 7.192
# Iteration #3 - Objective function value:  0.03 - time: 6.599
# Iteration #4 - Objective function value:  0.03 - time: 7.320
# Iteration #5 - Objective function value:  0.03 - time: 7.253
# Iteration #6 - Objective function value:  0.03 - time: 6.268
# Iteration #7 - Objective function value:  0.03 - time: 7.230
# Iteration #8 - Objective function value:  0.03 - time: 6.291
# Iteration #9 - Objective function value:  0.03 - time: 7.268
# Iteration #10 - Objective function value:  0.03 - time: 6.337
# Iteration #11 - Objective function value:  0.03 - time: 7.429
# Iteration #12 - Objective function value:  0.03 - time: 6.311
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.41806483268737793
# repetition =  20
# Iteration #0 - Objective function value:  0.05 - time: 7.354
# Iteration #1 - Objective function value:  0.05 - time: 6.491
# Iteration #2 - Objective function value:  0.03 - time: 7.701
# Iteration #3 - Objective function value:  0.03 - time: 7.555
# Iteration #4 - Objective function value:  0.03 - time: 6.502
# Iteration #5 - Objective function value:  0.03 - time: 7.628
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.20512747764587402
# repetition =  21
# Iteration #0 - Objective function value:  0.04 - time: 6.543
# Iteration #1 - Objective function value:  0.04 - time: 7.930
# Iteration #2 - Objective function value:  0.04 - time: 7.083
# Iteration #3 - Objective function value:  0.04 - time: 7.356
# Iteration #4 - Objective function value:  0.03 - time: 7.684
# Iteration #5 - Objective function value:  0.03 - time: 6.765
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.6205521821975708
# repetition =  22
# Iteration #0 - Objective function value:  0.08 - time: 7.658
# Iteration #1 - Objective function value:  0.02 - time: 6.635
# Iteration #2 - Objective function value:  0.02 - time: 7.613
# Iteration #3 - Objective function value:  0.02 - time: 6.914
# Iteration #4 - Objective function value:  0.02 - time: 6.871
# Iteration #5 - Objective function value:  0.02 - time: 7.485
# Iteration #6 - Objective function value:  0.02 - time: 6.330
# Iteration #7 - Objective function value:  0.02 - time: 7.415
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.45098915696144104
# repetition =  23
# Iteration #0 - Objective function value:  0.24 - time: 6.484
# Iteration #1 - Objective function value:  0.20 - time: 7.704
# Iteration #2 - Objective function value:  0.17 - time: 6.472
# Iteration #3 - Objective function value:  0.03 - time: 7.541
# Iteration #4 - Objective function value:  0.03 - time: 6.871
# Iteration #5 - Objective function value:  0.03 - time: 7.072
# Iteration #6 - Objective function value:  0.03 - time: 7.560
# Iteration #7 - Objective function value:  0.03 - time: 6.419
# Iteration #8 - Objective function value:  0.03 - time: 7.584
# Iteration #9 - Objective function value:  0.03 - time: 6.461
# Iteration #10 - Objective function value:  0.03 - time: 7.669
# Iteration #11 - Objective function value:  0.03 - time: 6.311
# Iteration #12 - Objective function value:  0.03 - time: 7.310
# Iteration #13 - Objective function value:  0.03 - time: 7.086
# Iteration #14 - Objective function value:  0.03 - time: 6.721
# Iteration #15 - Objective function value:  0.03 - time: 7.313
# Iteration #16 - Objective function value:  0.03 - time: 6.362
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.22373530268669128
# repetition =  24
# Iteration #0 - Objective function value:  0.11 - time: 8.237
# Iteration #1 - Objective function value:  0.05 - time: 6.629
# Iteration #2 - Objective function value:  0.05 - time: 7.577
# Iteration #3 - Objective function value:  0.05 - time: 6.943
# Iteration #4 - Objective function value:  0.05 - time: 7.017
# Iteration #5 - Objective function value:  0.05 - time: 7.369
# Iteration #6 - Objective function value:  0.05 - time: 6.495
# Iteration #7 - Objective function value:  0.05 - time: 7.484
# Iteration #8 - Objective function value:  0.05 - time: 6.312
# Iteration #9 - Objective function value:  0.03 - time: 7.508
# Iteration #10 - Objective function value:  0.03 - time: 6.265
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.2507465183734894
# repetition =  25
# Iteration #0 - Objective function value:  0.04 - time: 7.523
# Iteration #1 - Objective function value:  0.04 - time: 6.895
# Iteration #2 - Objective function value:  0.04 - time: 6.875
# Iteration #3 - Objective function value:  0.04 - time: 7.358
# Iteration #4 - Objective function value:  0.04 - time: 6.287
# Iteration #5 - Objective function value:  0.04 - time: 7.455
# Iteration #6 - Objective function value:  0.04 - time: 6.406
# Iteration #7 - Objective function value:  0.04 - time: 7.491
# Iteration #8 - Objective function value:  0.04 - time: 6.272
# Iteration #9 - Objective function value:  0.04 - time: 7.455
# Iteration #10 - Objective function value:  0.04 - time: 6.874
# Iteration #11 - Objective function value:  0.04 - time: 7.156
# Iteration #12 - Objective function value:  0.04 - time: 7.525
# Iteration #13 - Objective function value:  0.04 - time: 6.259
# Iteration #14 - Objective function value:  0.04 - time: 7.365
# Iteration #15 - Objective function value:  0.03 - time: 6.344
# Iteration #16 - Objective function value:  0.02 - time: 7.408
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.340624064207077
# repetition =  26
# Iteration #0 - Objective function value:  0.19 - time: 6.398
# Iteration #1 - Objective function value:  0.06 - time: 7.171
# Iteration #2 - Objective function value:  0.02 - time: 6.272
# Iteration #3 - Objective function value:  0.02 - time: 7.300
# Iteration #4 - Objective function value:  0.02 - time: 6.891
# Iteration #5 - Objective function value:  0.02 - time: 6.778
# Iteration #6 - Objective function value:  0.02 - time: 7.618
# Iteration #7 - Objective function value:  0.02 - time: 6.590
# Iteration #8 - Objective function value:  0.02 - time: 7.649
# Iteration #9 - Objective function value:  0.02 - time: 6.711
# Iteration #10 - Objective function value:  0.02 - time: 7.418
# Iteration #11 - Objective function value:  0.02 - time: 6.610
# Iteration #12 - Objective function value:  0.02 - time: 7.333
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.24207033216953278
# repetition =  27
# Iteration #0 - Objective function value:  0.03 - time: 7.576
# Iteration #1 - Objective function value:  0.03 - time: 6.354
# Iteration #2 - Objective function value:  0.03 - time: 7.574
# Iteration #3 - Objective function value:  0.03 - time: 6.361
# Iteration #4 - Objective function value:  0.03 - time: 7.441
# Iteration #5 - Objective function value:  0.03 - time: 6.267
# Iteration #6 - Objective function value:  0.03 - time: 7.363
# Iteration #7 - Objective function value:  0.03 - time: 6.639
# Iteration #8 - Objective function value:  0.03 - time: 7.212
# Iteration #9 - Objective function value:  0.03 - time: 7.347
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Mean Squared Error on Test Set: 0.3124244809150696
# repetition =  28
# Iteration #0 - Objective function value:  0.26 - time: 6.456
# Iteration #1 - Objective function value:  0.11 - time: 7.417
# Iteration #2 - Objective function value:  0.04 - time: 6.405
# Iteration #3 - Objective function value:  0.04 - time: 7.376
# Iteration #4 - Objective function value:  0.04 - time: 6.297
# Iteration #5 - Objective function value:  0.04 - time: 7.449
# Iteration #6 - Objective function value:  0.04 - time: 6.228
# Iteration #7 - Objective function value:  0.04 - time: 7.332
# Iteration #8 - Objective function value:  0.04 - time: 6.723
# Iteration #9 - Objective function value:  0.04 - time: 7.132
# Iteration #10 - Objective function value:  0.04 - time: 7.519
# Iteration #11 - Objective function value:  0.04 - time: 6.418
# Iteration #12 - Objective function value:  0.04 - time: 7.353
# Iteration #13 - Objective function value:  0.04 - time: 6.346
# Iteration #14 - Objective function value:  0.04 - time: 7.570
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error on Test Set: 0.34492748975753784
# repetition =  29
# [[50, 14, 0.3, 1.5, 108.01558685500001, 0.1275332], [50, 11, 0.3, 1.5, 74.61612601299998, 0.32829437], [50, 9, 0.3, 1.5, 59.550925635, 0.31733227], [50, 11, 0.3, 1.5, 73.766716245, 0.45711106], [50, 6, 0.3, 1.5, 41.70804350399999, 0.23362964], [50, 9, 0.3, 1.5, 62.28836832100001, 0.26101115], [50, 10, 0.3, 1.5, 68.76643582500003, 0.42997444], [50, 17, 0.3, 1.5, 115.40432733199998, 0.47921687], [50, 13, 0.3, 1.5, 118.83673943600002, 0.5070424], [50, 8, 0.3, 1.5, 65.03991618300006, 1.0822113], [50, 6, 0.3, 1.5, 40.93149851199996, 0.4549502], [50, 14, 0.3, 1.5, 97.00349110000002, 0.5229174], [50, 10, 0.3, 1.5, 72.39489770400019, 0.2188192], [50, 8, 0.3, 1.5, 55.678114541000014, 0.6407799], [50, 15, 0.3, 1.5, 103.44852808400015, 0.45924276], [50, 8, 0.3, 1.5, 55.31765371899996, 0.2557679], [50, 12, 0.3, 1.5, 83.71991419400001, 0.20827854], [50, 16, 0.3, 1.5, 110.59787115299991, 0.21484388], [50, 13, 0.3, 1.5, 90.9144817209999, 0.5410249], [50, 6, 0.3, 1.5, 40.97485702900008, 0.3080015], [50, 13, 0.3, 1.5, 89.25190945100007, 0.41806483], [50, 6, 0.3, 1.5, 43.23380397699998, 0.20512748], [50, 6, 0.3, 1.5, 43.365864539000086, 0.6205522], [50, 8, 0.3, 1.5, 56.92277400800003, 0.45098916], [50, 17, 0.3, 1.5, 118.94531516700022, 0.2237353], [50, 11, 0.3, 1.5, 77.84285702399984, 0.25074652], [50, 17, 0.3, 1.5, 118.95112530699998, 0.34062406], [50, 13, 0.3, 1.5, 90.74294826100004, 0.24207033], [50, 10, 0.3, 1.5, 70.14004989299974, 0.31242448], [50, 15, 0.3, 1.5, 104.0259267409997, 0.3449275]]

# %%
df_pso = pd.DataFrame(data = pso_variables)

print(df_pso)
# Out:
#      0   1    2    3           4         5
# 0   50  14  0.3  1.5  108.015587  0.127533
# 1   50  11  0.3  1.5   74.616126  0.328294
# 2   50   9  0.3  1.5   59.550926  0.317332
# 3   50  11  0.3  1.5   73.766716  0.457111
# 4   50   6  0.3  1.5   41.708044  0.233630
# 5   50   9  0.3  1.5   62.288368  0.261011
# 6   50  10  0.3  1.5   68.766436  0.429974
# 7   50  17  0.3  1.5  115.404327  0.479217
# 8   50  13  0.3  1.5  118.836739  0.507042
# 9   50   8  0.3  1.5   65.039916  1.082211
# 10  50   6  0.3  1.5   40.931499  0.454950
# 11  50  14  0.3  1.5   97.003491  0.522917
# 12  50  10  0.3  1.5   72.394898  0.218819
# 13  50   8  0.3  1.5   55.678115  0.640780
# 14  50  15  0.3  1.5  103.448528  0.459243
# 15  50   8  0.3  1.5   55.317654  0.255768
# 16  50  12  0.3  1.5   83.719914  0.208279
# 17  50  16  0.3  1.5  110.597871  0.214844
# 18  50  13  0.3  1.5   90.914482  0.541025
# 19  50   6  0.3  1.5   40.974857  0.308001
# 20  50  13  0.3  1.5   89.251909  0.418065
# 21  50   6  0.3  1.5   43.233804  0.205127
# 22  50   6  0.3  1.5   43.365865  0.620552
# 23  50   8  0.3  1.5   56.922774  0.450989
# 24  50  17  0.3  1.5  118.945315  0.223735
# 25  50  11  0.3  1.5   77.842857  0.250747
# 26  50  17  0.3  1.5  118.951125  0.340624
# 27  50  13  0.3  1.5   90.742948  0.242070
# 28  50  10  0.3  1.5   70.140050  0.312424
# 29  50  15  0.3  1.5  104.025927  0.344927

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
with open('/content/drive/MyDrive/TESI/Colab Notebooks/IT 6-18, POP=50, X_MAX=1.5/PSO_SPHFUN ITERATION 6-18.txt', 'a') as file:
        df_pso.to_csv(file, sep = '\t', index=False, mode= 'a', header = ['x','x','x','x','x','x'])
